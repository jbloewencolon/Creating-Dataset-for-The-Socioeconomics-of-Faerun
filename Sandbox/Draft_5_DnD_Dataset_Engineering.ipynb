# %% [markdown]
# <a href="https://colab.research.google.com/github/jbloewencolon/The-Demographics-of-Faerun/blob/main/Draft_5_DnD_Dataset_Engineering.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import random

# %%
# Define the file path (it seems you've already specified it)
file_path = '/content/drive/MyDrive/Colab Notebooks/DnD/fictional_data.xlsx'

# %%
#Define Constants
species = ["humans", "halflings", "half-orcs", "half-drow", "half-elves", "elves", "dwarves", "gnomes", "goblins", "lizardfolk", "yuan-ti", "orcs", "ogres", "asabi", "gnolls",
           "pterafolk", "drow", "centaurs", "wemics", "humanoids"]
columns = ["City", "Continent", "Nation/Region", "Government Type"] + [f"{s} Count" for s in species] + ["Population of City", "Average Age of Population", "Population Distribution"
        "Typical Cause of Death", "Wizarding School", "Active Economy (Gold)", "Hidden Economy (Gold)", "Known Treasure Value", "Rumored Treasure Value",
        "Dragon Sightings", "Tax Rate", "Major Industries", "Major Resources", "Number of Landowners", "Number of Homeowners", "Average Rent",
        "Number of Peasants", "Average Debt by Household", "Number of Nobility", "Number of Active Adventurers",
        "Number of Active Wizards", "Likelihood of Getting Cursed", "Danger Level", "Openness to Strangers",
        "Notable Landmarks", "Environmental Climate", "Average Temperature", "Average Rainfall", "Political Climate",
        "Magical Climate", "Fate Ranking", "Total Gold in Region"
    ]
city_names = [
    "Abriymoch", "Aelor", "Ageadren", "Airspur", "Akanax",
    "Akkaido", "Al-Anwahr", "Alashan", "Almraiven", "Ammathluir", "Ammathtar",
    "Anaxadren", "Araugul", "Ariel-than", "Asple", "Assam", "Athkatla",
    "Aventine", "Azumar", "Balanzia", "Baldur's Gate", "Beluir", "Beradandar",
    "Berydren", "Bhutan", "Bidnop So", "Blingdenstone", "Bral", "Branestria",
    "Callidae", "Calimport", "Castle Darkhold", "Cathyr", "Cedarsproke", "Chaoyang",
    "Chaul'mur'ssin", "Chavyondat", "Cheju", "Choshein", "Chrysalis",
    "Chunming", "Cimbar", "Citadel of Ice and Steel", "Citadel Adbar", "Citadel Felbarr",
    "Citadel of Ten Thousand Pearls", "City of Brass", "City of Caverns", "City of Glass",
    "City of the Werecrocodiles", "Clorlyth'na'tsheen", "Corrant", "Dalekeva",
    "Dalelost", "Darka", "Darmshall", "Darrawn", "Dashadjen", "Dauntshield",
    "Dawnfire", "Deepearth", "Delia", "Delselar", "Delzimmer", "Derlusk",
    "Dhinnilith", "Dilpur", "Djerad Kethendi", "Djerad Kusold", "Dloemen", "Dojyu",
    "Dolblunde", "Dralpur", "Drelagara", "Duhlnarim", "Dunspeirrin", "Dusklan",
    "Dyon G'ennivalz", "Elgrin Fau", "Ereshkigal", "Evereska", "Everlund", "Evermeet", "Evernight",
    "Eylea", "Faenasuor", "Fatula Chupa", "Fij", "Fluvenilstra", "Flyndagol",
    "Fochu", "Foo Nakar", "Forharn", "Fukiow", "Gharreil", "Gheldaneth",
    "Gifu", "Gizekhtet (city)", "Glister", "Gloomwrought", "Gnarhelm (city)", "Goliad",
    "Gontal City", "Guallidurth", "Gundbarg", "Gurdeth", "Halagard", "Hammerstaad",
    "Harglast", "Haunvaerune", "Hazuth", "Helbrester", "Heldapan", "Helgabal",
    "Helm's Hold", "Herath", "Hethar", "Hilbrand", "Hisari", "Hlammach",
    "Huorm", "Iiso", "Ilimar", "Iliphanar", "Illul", "Iltkazar",
    "Imdolphyn", "Immurk's Hold", "In'ani", "Inupras", "Iriaebor", "Ironfang Deep",
    "Ironspur", "Ithmong (Lapaliiya)", "Ixtzul", "Jangling Hiter", "Jasuga", "Jhachalkhyn",
    "Jhalhoran", "Jhothûn (city)", "Joya", "Jugicha", "Kanaglym", "Karak",
    "Karffbadh", "Kaspar", "Keltar", "Khaerbaal", "Khampo", "Koje",
    "Konang Pen", "Konigheim", "Kormul", "Kourmira", "Kressilacc", "Kuda",
    "Kuo Te' Lung", "Kushk", "Lasdur", "Lheshayl", "Lipo",
    "Lith My'athar", "Llorbauth", "Llurth Dreier", "Lothen of the Silver Spires", "Luenath", "Lundeth (Thindol)",
    "Lushpool", "Luskan", "Lylorn", "Maerlar", "Malduir", "Malsheem",
    "Malydren", "Manass", "Marabaya", "Marangor", "Marrauk", "Maxal",
    "Melvaunt", "Messemprar", "Mhairhetel", "Mictlatepec", "Mithral Hall",
    "Minauros (city)", "Mirabar", "Mordulkin", "Morvar", "Motra", "Mreyelundar",
    "Mulmaster", "Multum", "Mussum", "Myrmyr", "Myth Adofhaer", "Myth Drannor",
    "Myth Nantar", "Nakamaru", "Narubel", "Nathong", "Neldorild", "Nesmé",
    "Nethjet", "Nethra", "Neverwinter", "New Sarshel", "Nivian", "Nonthal",
    "Northkeep", "Nycopolis", "Obbolor", "Oberon's Hold", "Occidian", "Oeble",
    "Ojy-do", "Okahira", "Old Stone Keep", "Old Vaelen", "Omu", "Ooltul",
    "Opawangchicheng", "Orlumbor", "Ormath", "Ormpetarr", "Ornthalas", "Oryndoll",
    "Osel", "Ossantil", "Oth", "Outentown", "Ozryn", "Paolan",
    "Paraelemental City of Conflagration", "Paraelemental City of Deluge", "Paraelemental City of Ooze",
    "Paraelemental City of Sleet", "Phandalin", "Phannaskul",
    "Phaervorul", "Phrenopolis", "Piaoliang", "Pinebluff", "Pirth City", "Piyapon",
    "Plague-Mort", "Plotsklan", "Port Castigliar", "Port Llast", "Port Nyanzaru", "Port of Ravens Bluff",
    "Poytakht", "Priapurl", "Procampur", "Purskul", "Pyarados", "Q'barra",
    "Q'Xorlarrin", "Qazat", "Quaervarr", "Quarmall", "Qu'ellar d'Uzunt", "Qu'ellarz'orl",
    "Radocan", "Raurokh", "Raven's Bluff", "Razalpartha", "Rekkar-Sarrat", "Relkath's Foot",
    "Reth", "Revonar", "Riatavin", "Rilauven", "Ruathym (city)", "Ruldoer",
    "Rylatar", "Saelmur", "Sakkors", "Saradush", "Sardolphyn", "Sarth",
    "Sattar", "Scardale", "Schamedar", "Schorin", "Scornubel", "Secomber", "Sekras",
    "Selgaunt", "Semkhrun", "Sepech", "Serôs (city)", "Setma'antar", "Sethlapurkha",
    "Shaboath", "Shade (city)", "Shadusk", "Shangban", "Shaundalar", "Sheirtalar",
    "Shi-Kuo", "Shindikuur", "Shoonach", "Shu Pao", "Shussel", "Sildeyuir",
    "Silverymoon", "Siluvanede", "Simbia", "Sintharla", "Sjorndorn", "Skullport", "Skuld",
    "Soorenar", "Sschindylryn", "Sshamath", "Stornanter", "Sudar", "Suldanessellar", "Sundabar",
    "Sunduluth", "Sungping", "Surkh", "Suzail", "Svartalfheim", "Taejin",
    "Tagorlad", "Takalai", "Takar", "Talab", "Talath Passar", "Talath Seren",
    "Talbot", "Talhund", "Talinie (city)", "Tammar", "Tantras", "Tasseldale",
    "Tchazzar", "Telantiwar", "Telflamm", "Telnarquel", "Telos City", "Telsorn",
    "Temar", "Termalaine", "Tethgard", "Thallar", "Thamor", "Thangorodrim",
    "Tharqualnaar", "Thayd", "Thelnam", "Thentia", "Thesk", "Thulanth",
    "Thultanthar", "Thundarlun", "Thundertree", "Thyat", "Tibet", "Tilverton",
    "Tith Tilendrothael", "Torsil", "Triboar", "Triel", "Tsurlagol", "Tu Pe",
    "Tulmon", "Tun Mi Lung", "Tuncer", "Tunfeng", "Tunzel", "Turmish (city)",
    "Twilight Hall", "Two Stars", "Tyar-Besil", "Ulgarth (city)", "Ulgarstat", "Umbergoth",
    "Umbraer", "Urkhar", "Urossos", "Uthmere", "Uzurr", "Vaasa (city)",
    "Valjevo Castle", "Vangal", "Velegrar", "Vilhon Reach", "Volothamp", "Voonlar",
    "Vor Rukoth", "V'ral", "Waterdeep", "Weeping War (city)", "Westgate", "Wheloon", "Winterkeep",
    "Xarcorr", "Xinlenal", "Xonthal's Tower", "Xynnar", "Yal Tengri", "Yaulazna",
    "Yhaunn", "Yhro 'Lamith", "Ylraphon", "Yuirwood", "Yunn Shicheng", "Za Si Tsan",
    "Zazesspur", "Zhentil Keep", "Zhenul", "Zindalankh", "Zokir"
    ]
top_cities = {
    "Waterdeep": {"Region": "Sword Coast", "Population": [340000, 360000]},
    "Skuld": {"Region": "Mulhorand", "Population": [190000, 210000]},
    "Calimport": {"Region": "Calimshan", "Population": [190000, 200000]},
    "Gheldaneth": {"Region": "Mulhorand", "Population": [170000, 175000]},
    "Unthalass": {"Region": "Unther", "Population": [160000, 170000]},
    "Suldolphor": {"Region": "Calimshan", "Population": [140000, 150000]},
    "Bezantur": {"Region": "Thay", "Population": [130000, 140000]},
    "Eltabbar": {"Region": "Thay", "Population": [120000, 130000]},
    "Zazesspur": {"Region": "Tethyr", "Population": [110000, 120000]},
    "Cimbar": {"Region": "Chessenta", "Population": [105000, 115000]},
    "Athkatla": {"Region": "Amn", "Population": [125000, 400000]},
}

Regions = {
    "The Chultan Peninsula": {
        "Samarach": {"total_population": (140000, 150000), "species_distribution": {"humans": 60, "goblins": 20, "lizardfolk": 10, "dwarves": 5, "pterafolk": 4}},
        "Thindol": {"total_population": (200000, 210000), "species_distribution": {"humans": 60, "goblins": 20, "lizardfolk": 10, "dwarves": 5, "pterafolk": 4}},
        "Tashalar": {"total_population": (80000, 900000), "species_distribution": {"humans": 94, "lizardfolk": 4, "yuan-ti": 1}},
        "Lapaliiya":{"total_population": None, "species_distribution": None},
        "Tharsult":{"total_population": None, "species_distribution": None},
    },
    "The Cold Lands": {
        "Damara": {"total_population": (1300000, 1400000), "species_distribution": {"humans": 87, "dwarves": 6, "halflings": 4, "half-orcs": 2}},
        "Narfell": {"total_population": (30000, 40000), "species_distribution": {"humans": 99}},
        "Vaasa": {"total_population": (140000, 150000), "species_distribution": {"humans": 60, "dwarves": 30, "orcs": 9}},
        "Hartsvale": {"total_population": (10000, 15000), "species_distribution": {"humans": 96}}
    },
    "The Heartlands": {
        "Cormyr": {"total_population": (1360000, 1370000), "species_distribution": {"humans": 85, "half-elves": 10, "elves": 4}},
        "Dalelands": {"total_population": (600000, 650000), "species_distribution": {"humans": 80, "drow": 6, "half-elves": 5, "elves": 4, "halflings": 2, "gnomes": 1, "dwarves": 1}},
        "The Moonsea": {"total_population": (1740000, 1750000), "species_distribution": {"humans": 69, "orcs": 10, "half-orcs": 6, "halflings": 5, "dwarves": 5, "ogres": 2, "gnomes": 2}},
        "Sembia": {"total_population": (2460000, 2470000), "species_distribution": {"humans": 96, "halflings": 3}},
        "The Vast": {"total_population": (1300000, 1400000), "species_distribution": {"humans": 78, "dwarves": 9, "halflings": 5, "elves": 3, "gnomes": 2, "half-elves": 1, "half-orcs": 1}},
        "The Western Heartlands": {"total_population": (1640000, 1650000), "species_distribution": {"humans": 78, "elves": 7, "half-elves": 4, "halflings": 4, "half-orcs": 3, "gnomes": 2, "dwarves": 1}},
    },
    "The Unapproachable East": {
        "Aglarond": {"total_population": (1206576, 1333584), "species_distribution": {"humans": 64, "half-elves": 30, "elves": 5}},
        "The Great Dale": {"total_population": (201096, 222264), "species_distribution": {"humans": 99}},
        "The Hordelands": {"total_population": (1269136, 1400624), "species_distribution": {"humans": 85, "gnolls": 8, "centaurs": 5, "dwarves": 1}},
        "Impiltur": {"total_population": (1145016, 1265544), "species_distribution": {"humans": 90, "dwarves": 5, "halflings": 4}},
        "Rashemen": {"total_population": (621756, 687204), "species_distribution": {"humans": 99}},
        "Thay": {"total_population": (4678560, 5171040), "species_distribution": {"humans": 62, "gnolls": 10, "orcs": 10, "dwarves": 8, "goblins": 5, "halflings": 4}},
        "Thesk": {"total_population": (812592, 898128), "species_distribution": {"humans": 85, "gnomes": 8, "orcs": 6}},
    },
    "The Island Kingdoms": {
        "Evermeet": {"total_population": (1575936, 1741824), "species_distribution": {"elves": 99}},
        "Moonshae Isles": {"total_population": (646380, 714420), "species_distribution": {"humans": 89, "halflings": 4, "elves": 3, "dwarves": 2, "half-elves": 1}},
        "Nelanther Isles": {"total_population": (2681, 2963), "species_distribution": {"orcs": 30, "humans": 20, "half-orcs": 15, "lizardfolk": 15, "ogres": 10, "humanoids": 9}},
        "Lantan":{"total_population": None, "species_distribution": None},
    },
    "The Lands of Intrigue/Empires of the Sands": {
        "Lake of Steam": {"total_population": (1658016, 1832544), "species_distribution": {"humans": 90, "halflings": 9}},
        "Amn": {"total_population": (2815344, 3111696), "species_distribution": {"humans": 83, "halflings": 15, "half-orcs": 1}},
        "Calimshan": {"total_population": (5072544, 5606496), "species_distribution": {"humans": 94, "half-orcs": 2, "halflings": 2, "half-elves": 1}},
        "Tethyr": {"total_population": (3583792, 3958928), "species_distribution": {"humans": 76, "halflings": 20, "elves": 3}},
        "Erlkazar": {"total_population": (60000, 70000), "species_distribution": {"humans": 57, "halflings": 10, "dwarves": 30, "elves": 3}},
    },
    "The North": {
        "The High Forest": {"total_population": (27634, 30542), "species_distribution": {"elves": 52, "gnolls": 12, "centaurs": 10, "orcs": 10, "half-elves": 5, "half-orcs": 5, "humans": 3, "halflings": 2}},
        "The Savage Frontier": {"total_population": (536256, 592704), "species_distribution": {"humans": 55, "orcs": 20, "dwarves": 5, "half-elves": 5, "elves": 4, "half-orcs": 4, "halflings": 4, "gnomes": 2}},
        "Luruar/The Silver Marches": {"total_population": (1036260, 1145340), "species_distribution": {"humans": 40, "dwarves": 20, "elves": 20, "half-elves": 10, "halflings": 5, "gnomes": 2, "half-orcs": 2}},
        "The Sword Coast": {"total_population": (627912, 694008), "species_distribution": {"humans": 65, "dwarves": 10, "orcs": 8, "half-orcs": 5, "elves": 4, "halflings": 4, "gnomes": 2, "half-elves": 1}},
        "Waterdeep & Surrounds": {"total_population": (1280448, 1415232), "species_distribution": {"humans": 64, "dwarves": 10, "elves": 10, "halflings": 5, "half-elves": 5, "gnomes": 3, "half-orcs": 2}},
    },
    "The Old Empires": {
        "Chessenta": {"total_population": (3217536, 3556224), "species_distribution": {"humans": 82, "halflings": 6, "dwarves": 5, "half-orcs": 4, "lizardfolk": 2}},
        "Mulhorand": {"total_population": (5072544, 5606496), "species_distribution": {"humans": 99}},
        "Unther": {"total_population": (4050743, 4477137), "species_distribution": {"humans": 94, "dwarves": 3, "halflings": 2}},
    },
    "The Shining South": {
        "The Great Rift": {"total_population": (1243512, 1374408), "species_distribution": {"dwarves": 96, "gnomes": 2, "halflings": 1}},
        "Halruaa": {"total_population": (1592352, 1760968), "species_distribution": {"humans": 90, "dwarves": 5, "halflings": 2, "elves": 1, "half-elves": 1}},
        "Luiren": {"total_population": (796176, 880984), "species_distribution": {"halflings": 92, "humans": 4, "elves": 2, "half-elves": 1}},
        "The Shaar": {"total_population": (558144, 616896), "species_distribution": {"humans": 60, "wemics": 15, "gnolls": 14, "centaurs": 10}},
        "Dambrath": {"total_population": (42000, 43000), "species_distribution": {"humans": 75, "half-drow": 15,}},
        "Durpar": {"total_population": "unknown", "species_distribution": "unknown"},
        "Estagund": {"total_population": "unknown", "species_distribution": "unknown"},
        "Var the Golden": {"total_population": "unknown", "species_distribution": "unknown"},
        "Veldorn": {"total_population": "unknown", "species_distribution": "unknown"},
    },
    "The Vilhon Reach": {
        "Chondath": {"total_population": (1883736, 2082024), "species_distribution": {"humans": 96, "elves": 2, "dwarves": 1}},
        "Sespech": {"total_population": (904932, 1000888), "species_distribution": {"humans": 96, "dwarves": 2, "elves": 1}},
        "Turmish": {"total_population": (1609768, 1777112), "species_distribution": {"humans": 78, "dwarves": 9, "halflings": 5, "elves": 3, "gnomes": 2, "half-elves": 1, "half-orcs": 1}},
    },
    "Others": {
        "wilderness, city-states": {"total_population": (870000, 880000), "species_distribution": "unknown"}
    }
}
nations = ["Aglarond", "Amn", "Calimshan", "Chessenta", "Chondath","Chult", "Cormyr", "Damara","Dambrath", "Dalelands", "Durpar", "Evermeet", "Estagund", "Erlkazar", "The Great Dale", "The Great Rift",
                "Halruaa", "Hartsvale", "The High Forest", "The Hordelands", "Impiltur", "Lake of Steam", "Lantan", "Lapaliiya", "Luiren","The Moonsea", "Moonshae Isles", "Mulhorand", "Narfell", "Nelanther Isles",
                "Rashemen", "The Savage Frontier", "The Shaar", "Sembia", "Sespech", "Luruar/The Silver Marches", "The Sword Coast","Tashalar","Tharsult", "Tethyr", "Thay", "Thesk", "Turmish", "Unther", "Waterdeep & Surrounds",
                "The Western Heartlands", "wilderness, city-states", "Vaasa","Var the Golden", "The Vast","Veldorn"]
government_types = ["Autocracy", "Bureaucracy", "Confederacy", "Democracy", "Dictatorship", "Feudalism", "Gerontocracy", "Hierarchy",
                    "Monarchy", "Magocracy", "Militocracy", "Matriarchy", "Oligarchy", "Patriarchy", "Meritocracy", "Plutocracy",
                    "Republic", "Kleptocracy", "Satrapy", "Theocracy"]
species_age_ranges = {
            "humans": [1, 100],
            "halflings": [1, 150],
            "half-elves": [1, 180],
            "half-orcs": [1, 75],
            "orcs": [1, 50],
            "elves": [1, 750],
            "dwarves": [1, 350],
            "gnomes": [1, 400]
        }
    # Setting up the percentage ranges of total population and city distribution for each species
species_percentage_of_total_population = {
    "humans": {"population_percentage_range": [75, 83]},
    "halflings": {"population_percentage_range": [6, 7]},
    "dwarves": {"population_percentage_range": [5, 6]},
    "half-elves": {"population_percentage_range": [3, 5]},
    "elves": {"population_percentage_range": [3, 5]},
    "half-orcs": {"population_percentage_range": [2, 3]},
    "gnomes": {"population_percentage_range": [.5, 2]},
}
Species_population_distribution_in_cities = {
    "humans": {"percentage": 100, "city_names": city_names},
    "halflings": {"percentage": 100, "city_names": city_names},
    "dwarves": [{"percentage": 50, "city_names": ["Mithral Hall", "Citadel Adbar", "Citadel Felbarr"]}, {"percentage": 50, "city_names": city_names}],
    "elves": [{"percentage": 80, "city_names": ["Silverymoon", "Evereska", "Evermeet", "Yuirwood", "Myth Nantar", "Waterdeep"]}, {"percentage": 20, "city_names": city_names}],
    "half-orcs": {"percentage": 100, "city_names": city_names},
    "gnomes": [{"percentage": 95, "city_names": ["Gharreil", "Gheldaneth", "Gifu", "Gizekhtet (city)", "Glister", "Gloomwrought", "Gnarhelm (city)", "Goliad",
    "Gontal City"]}, {"percentage": 5, "city_names": city_names}],
}
total_population = np.random.randint(66e6, 70e6)
total_economy = np.random.uniform(80e6, 100e6)
notable_landmarks = ["Landmark1", "Landmark2"]

# %%
def generate_city_data(city_name, region, min_pop, max_pop, remaining_population, remaining_economy, species):
    population = np.random.randint(min_pop, min(max_pop, remaining_population) + 1)
    remaining_population -= population

    species_percentages = np.random.dirichlet(np.ones(len(species)), size=1)[0] * 100
    species_percentages = [round(val, 2) for val in species_percentages]
    species_counts = np.random.multinomial(population, [1/len(species)]*len(species))

    # Calculate economy distribution
    if remaining_population == 0:  # last city
        active_economy = remaining_economy / 2
        hidden_economy = remaining_economy / 2
    else:
        max_economy_for_city = remaining_economy - 100  # Reserve some economy for other cities
        active_economy = np.random.uniform(100, max_economy_for_city / 2)
        hidden_economy = np.random.uniform(100, max_economy_for_city - active_economy)
    remaining_economy -= (active_economy + hidden_economy)

    data = {"City": city_name, "Region": region, "Population": population,
            "Active Economy": active_economy, "Hidden Economy": hidden_economy}

    for idx, spec in enumerate(species):
        data[f"{spec} Count"] = species_counts[idx]
        data[f"Percentage of population {spec}"] = species_percentages[idx]
        data[f"Number of {spec}"] = (species_percentages[idx] / 100) * population

    data["Danger Level"] = adjust_danger_level(data)
    data["Magical Climate"] = calculate_magical_climate(data)

    return data, remaining_population, remaining_economy

# %%
def assign_species_to_cities(data, species):
    for city in data:
        city_data = data[city]
        total_population = city_data["Population"]

        species_data = {spec: city_data[f"{spec} Count"] for spec in species}
        max_species = max(species_data, key=species_data.get)

        city_data["Dominant Species"] = max_species
        city_data["Dominant Species Count"] = species_data[max_species]
        city_data["Dominant Species Percentage"] = (species_data[max_species] / total_population) * 100

        min_species = min(species_data, key=species_data.get)
        city_data["Minor Species"] = min_species
        city_data["Minor Species Count"] = species_data[min_species]
        city_data["Minor Species Percentage"] = (species_data[min_species] / total_population) * 100

# %%
def calculate_average_age(data, species):
    for city in data:
        city_data = data[city]
        total_population = city_data["Population"]

        total_age = sum(city_data[f"{spec} Average Age"] * city_data[f"{spec} Count"] for spec in species)
        city_data["Average Age"] = total_age / total_population

# %%
if __name__ == "__main__":
    # Step 1: Initialization
    regions = [...]
    species = [...]
    min_pop = ...
    max_pop = ...
    total_pop = ...
    total_economy = ...

    data = {}
    remaining_population = total_pop
    remaining_economy = total_economy

    # Step 2: Generate City Data
    for region in regions:
        cities_in_region = generate_city_list(region)
        for city_name in cities_in_region:
            data[city_name], remaining_population, remaining_economy = generate_city_data(
                city_name, region, min_pop, max_pop, remaining_population, remaining_economy, species
            )

    # Step 3: Assign Species to Cities and Calculate Average Age
    assign_species_to_cities(data, species)
    calculate_average_age(data, species)

    # Step 4: Additional Calculations (if any)

    # Step 5: Output Results (e.g., saving data to a file)

# %%
import numpy as np
import pandas as pd

# Constants and lists defined here...

def generate_city_data(city_name, region, min_pop, max_pop, remaining_population, remaining_economy, species):
    # Function body as you defined...

def generate_data_for_all_cities(city_list, region_list, species):
    data = []
    remaining_population = total_population
    remaining_economy = total_economy

    for region in region_list:
        for city_name in city_list:
            min_pop, max_pop = 1000, 10000  # Set appropriate min and max population values here
            city_data, remaining_population, remaining_economy = generate_city_data(city_name, region, min_pop, max_pop, remaining_population, remaining_economy, species)
            data.append(city_data)

    return data

# Use other defined functions for additional calculations here...

# Generate data for all cities and create a dataframe
city_data_list = generate_data_for_all_cities(city_names, region_names, species)
df = pd.DataFrame(city_data_list)

# Add other columns to the dataframe here...

# Save the dataframe to a CSV file
df.to_csv('city_data.csv', index=False)

# %%
def generate_city_data(city_name, region, remaining_population, remaining_economy, species):
    population = np.random.randint(0, min(10000, remaining_population) + 1)
    remaining_population -= population

    species_percentages = np.random.dirichlet(np.ones(len(species)), size=1)[0] * 100
    species_percentages = [round(val, 2) for val in species_percentages]
    species_counts = np.random.multinomial(population, [1/len(species)]*len(species))

    # ... (Rest of your function here) ...

    return data, remaining_population, remaining_economy

def assign_species_to_cities(data, species):
    for city_data in data:
        total_population = city_data["Population"]

        species_data = {spec: city_data[f"{spec} Count"] for spec in species}
        max_species = max(species_data, key=species_data.get)

        city_data["Dominant Species"] = max_species
        city_data["Dominant Species Count"] = species_data[max_species]
        city_data["Dominant Species Percentage"] = (species_data[max_species] / total_population) * 100 if total_population > 0 else 0

        min_species = min(species_data, key=species_data.get)
        city_data["Minor Species"] = min_species
        city_data["Minor Species Count"] = species_data[min_species]
        city_data["Minor Species Percentage"] = (species_data[min_species] / total_population) * 100 if total_population > 0 else 0

def calculate_average_age(data, species):
    for city_data in data:
        total_population = city_data["Population"]

        total_age = sum(city_data[f"{spec} Average Age"] * city_data[f"{spec} Count"] for spec in species)
        city_data["Average Age"] = total_age / total_population if total_population > 0 else 0

def generate_data_for_all_cities(city_list, region_list, species):
    data = []
    remaining_population = total_population
    remaining_economy = total_economy

    for region in region_list:
        for city_name in city_list:
            city_data, remaining_population, remaining_economy = generate_city_data(city_name, region, remaining_population, remaining_economy, species)
            data.append(city_data)

    assign_species_to_cities(data, species)
    calculate_average_age(data, species)

    return data

# Generate data for all cities and create a dataframe
city_data_list = generate_data_for_all_cities(city_names, region_names, species)
df = pd.DataFrame(city_data_list)

# Add other columns to the dataframe here...

# Save the dataframe to a CSV file
df.to_csv('city_data.csv', index=False)

# %%
# Function Definitions
def select_industries_and_resources(industries, resources):
    selected_industries = np.random.choice(industries, size=np.random.randint(1, len(industries)), replace=False)
    selected_resources = np.random.choice(resources, size=np.random.randint(1, len(resources)), replace=False)
    return selected_industries, selected_resources

def assign_population_to_cities(city_data, total_population, top_cities_population):
    remaining_population = total_population - top_cities_population
    percentages = np.random.dirichlet(np.ones(len(city_data) - len(top_cities)), size=1)[0]
    for i, city in city_data.iloc[len(top_cities):].iterrows():
        city_population = int(remaining_population * percentages[i - len(top_cities)])
        city_data.at[i, 'Population of City'] = city_population
        remaining_population -= city_population

def assign_species_to_cities(city_data, species_data):
    for species, data in species_data.items():
        for i, city in city_data.iterrows():
            city_population = city['Population of City']
            species_percentage = random.uniform(data[0][0], data[0][1])
            species_count = int((species_percentage / 100) * city_population)
            city_data.at[i, f"{species} Count"] = species_count
            city_data.at[i, 'Population Distribution'][species] = species_percentage

# Step 1: Calculate total population of top cities
top_cities_population = sum([np.random.randint(details['Population'][0], details['Population'][1] + 1) for details in top_cities.values()])

# Step 2: Assign population to other cities
assign_population_to_cities(df, total_population, top_cities_population)

# Step 3: Assign species to cities
for i in range(len(df)):
    df.at[i, 'Population Distribution'] = {}

assign_species_to_cities(df, species_data)

def calculate_average_age(row, species_age_ranges):
    weighted_ages = sum([(row[f'Percentage of population {species}'] / 100) * np.random.uniform(low=species_age_ranges[species][0], high=species_age_ranges[species][1]) for species in species_age_ranges])
    return weighted_ages

def calculate_dragon_sightings(row):
    region_gold = row['Total Gold in Region']
    max_sightings = min(50, row['Fate Ranking'] + region_gold // 1e6)
    return np.random.randint(0, max_sightings + 1)

def adjust_danger_level(row):
    danger_level = row['Danger Level']
    if row['Percentage of population Orcs'] > 0:
        danger_level += 1
    if row['Percentage of population Elves'] > 0:
        danger_level -= 1
    return min(max(1, danger_level), 10)

# Function to calculate magical climate
def calculate_magical_climate(row):
    return row['Dragon Sightings'] * 0.1 + row['Number of Active Wizards'] * 0.5

def check_data_consistency(data, species):
    # Adjusting Population Distribution to 100
    species_keys = [f"Percentage of population {s}" for s in species]
    total_distribution = sum(data[key] for key in species_keys if key in data)
    if total_distribution != 100:
        for key in species_keys:
            if key in data:
                data[key] = (data[key] / total_distribution) * 100

def calculate_openness_to_strangers(row):
    openness = row['Openness to Strangers']
    if row['Percentage of population Elves'] > 0 or row['Percentage of population Orcs'] > 0:
        openness -= 2
    return min(max(0, openness), 10)

# %%
#Data Generation
data_list = []
num_cities = len(city_names)
total_population = np.random.randint(66e6, 70e6)
remaining_population = total_population
total_economy = np.random.uniform(80e6, 100e6)
remaining_economy = total_economy
unused_city_names = list(city_names)

    # Add top cities first
for city, details in top_cities.items():
    population = np.random.randint(details["Population"][0], details["Population"][1]+1)
    remaining_population -= population

    data = {
            "City": city,
            "Region": details["Region"],
            "Population of City": population,
            "Continent": np.random.choice(nation_names),
            "Government Type": np.random.choice(government_types),
            "Typical Cause of Death": np.random.choice(causes_of_death),
            "Wizarding School": np.random.choice(["Yes", "No"]),
            "Known Treasure Value": np.random.randint(1e6, 10e6),
            "Rumored Treasure Value": np.random.randint(1e6, 10e6),
            "Dragon Sightings": np.random.randint(0, 50),
            "Tax Rate": np.random.randint(0, 100),
            "Major Industries": np.random.choice(major_industries),
            "Major Resources": np.random.choice(major_resources),
            "Number of Landowners": np.random.randint(1, 200),
            "Number of Homeowners": np.random.randint(10, 10000),
            "Average Rent": np.random.randint(1, 5000),
            "Number of Peasants": np.random.randint(10, 50000),
            "Average Debt by Household": np.random.randint(0, 100000),
            "Number of Nobility": np.random.randint(0, 5000),
            "Number of Active Adventurers": np.random.randint(0, 200),
            "Number of Active Wizards": np.random.randint(0, 20),
            "Likelihood of Getting Cursed": np.random.randint(0, 10),
            "Danger Level": np.random.randint(0, 10),
            "Openness to Strangers": np.random.randint(0, 100),
            "Notable Landmarks": np.random.choice(notable_landmarks),
            "Environmental Climate": np.random.choice(["Tropical", "Temperate", "Arctic", "Desert", "Tundra"]),
            "Average Temperature": np.random.randint(-30, 50),
            "Average Rainfall": np.random.randint(0, 500),
            "Political Climate": np.random.randint(0, 100),
            "Magical Climate": np.random.randint(0, 10),
            "Fate Ranking": np.random.randint(0, 10),
            "Total Gold in Region": total_economy
        }

    data_list.append(data)

    # After adding top cities
for city, details in top_cities.items():
      population = np.random.randint(details["Population"][0], details["Population"][1]+1)
      remaining_population -= population
      data_list.append({"City": city, "Region": details["Region"], "Population of City": population, # ... other details here ...
            })

num_cities -= len(top_cities)

# Now ensure remaining_population is at least num_cities * 100 (or other minimum population per city)
remaining_population = max(remaining_population, num_cities * 100)

for i in range(num_cities):
     if i == num_cities - 1:
         city_population = remaining_population
     else:
         city_population = np.random.randint(100, min(350000, max(100, remaining_population - num_cities * 100 + 1)))
     remaining_population -= city_population

species_percentages = np.random.dirichlet(np.ones(len(species)), size=1)[0] * 100
species_percentages = [round(val, 2) for val in species_percentages]

# If it's the last city, distribute the remaining economy equally between active and hidden economies
if i == num_cities - 1:
    active_economy = remaining_economy / 2
    hidden_economy = remaining_economy / 2
else:
    max_economy_for_city = remaining_economy - (num_cities - i - 1) * 100  # Reserve some economy for other cities
    active_economy = np.random.uniform(100, max_economy_for_city / 2)  # Generating random active economy
    hidden_economy = np.random.uniform(100, max_economy_for_city - active_economy)  # Remaining for hidden economy

# Subtracting the utilized economy from the remaining economy
remaining_economy -= (active_economy + hidden_economy)

if unused_city_names:
    city_name = np.random.choice(unused_city_names)
    unused_city_names.remove(city_name)  # Remove the selected city name from the unused list
else:
    city_name = "New City " + str(i)  # Generate a new city name if all names from the list have been used

data = {
            "City": city,
            "Region": details["Region"],
            "Population of City": population,
            "Region": np.random.choice(region_names),
            "Nation": np.random.choice(nation_names),
            "Government Type": np.random.choice(government_types),
            "Population of City": city_population,
            "Typical Cause of Death": np.random.choice(causes_of_death),
            "Wizarding School": np.random.choice(["Yes", "No"]),
            "Known Treasure Value": np.random.randint(1e6, 10e6),
            "Rumored Treasure Value": np.random.randint(1e6, 10e6),
            "Dragon Sightings": np.random.randint(0, 50),
            "Tax Rate": np.random.randint(0, 100),
            "Major Industries": np.random.choice(major_industries),
            "Major Resources": np.random.choice(major_resources),
            "Number of Landowners": np.random.randint(1, 200),
            "Number of Homeowners": np.random.randint(10, 10000),
            "Average Rent": np.random.randint(1, 5000),
            "Number of Peasants": np.random.randint(10, 50000),
            "Average Debt by Household": np.random.randint(0, 100000),
            "Number of Nobility": np.random.randint(0, 5000),
            "Number of Active Adventurers": np.random.randint(0, 200),
            "Number of Active Wizards": np.random.randint(0, 20),
            "Likelihood of Getting Cursed": np.random.randint(0, 10),
            "Danger Level": np.random.randint(0, 10),
            "Openness to Strangers": np.random.randint(0, 100),
            "Notable Landmarks": np.random.choice(notable_landmarks),
            "Environmental Climate": np.random.choice(["Tropical", "Temperate", "Arctic", "Desert", "Tundra"]),
            "Average Temperature": np.random.randint(-30, 50),
            "Average Rainfall": np.random.randint(0, 500),
            "Political Climate": np.random.randint(0, 100),
            "Magical Climate": np.random.randint(0, 10),
            "Fate Ranking": np.random.randint(0, 10),
            "Total Gold in Region": total_economy
        }

# Check and adjust data consistency
check_data_consistency(data, species)

species_counts = np.random.multinomial(city_population, [1/len(species)]*len(species))
species_percentages = [int((count / city_population) * 100) for count in species_counts]
data['Population Distribution'] = dict(zip(species, species_percentages))

for idx, spec in enumerate(species):
    data[f"{spec} Count"] = species_counts[idx]
    data[f"Percentage of population {spec}"] = species_percentages[idx]
    data[f"Number of {spec}"] = (species_percentages[idx] / 100) * city_population

data['Population Distribution'] = {spec: species_percentages[idx] for idx, spec in enumerate(species)}

# Adjust danger level and magical climate after setting the species percentage of population
data["Danger Level"] = adjust_danger_level(data)
data["Magical Climate"] = calculate_magical_climate(data)
data['Active Economy (Gold)'] = active_economy
data['Hidden Economy (Gold)'] = hidden_economy

# Add the data dictionary to the list
data_list.append(data)

# Creating and sorting the dataframe
df = pd.DataFrame(data_list)
df = df.sort_values(by='City')

for species, data in species_data.items():
    adjust_population_distribution(df, species, data[0], data[1])

# Check total values
if df['Population of City'].sum() > total_population:
    print("Warning: Population exceeds limit. Regenerating data.")
    return data_generator(num_cities)

if df['Active Economy (Gold)'].sum() > total_economy:
    print("Warning: Economy exceeds limit. Regenerating data.")
    return data_generator(num_cities)
# Out:
# No cities available to distribute population.
# No cities available to distribute population.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-59-46d0472b0b17> in <cell line: 156>()
#     155
#     156 for species, data in species_data.items():
# --> 157     adjust_population_distribution(df, species, data[0], data[1])
#     158
#     159 # Check total values
#
# <ipython-input-52-dcc7d3d88abc> in adjust_population_distribution(city_data, species, percentage_range, city_count)
#      29         else:
#      30             city_data.at[i, f"{species} Count"] = each_city_population
# ---> 31             city_data.at[i, 'Population Distribution'][species] = (each_city_population / city['Population of City']) * 100
#      32
#      33 def calculate_average_age(row, species_age_ranges):
#
# TypeError: 'float' object does not support item assignment

# %%
df.head()
# Out:
#          City     Region  Population of City   Nation Government Type  \
# 19   Athkatla        Amn              117679      NaN             NaN
# 8    Athkatla        Amn              110659  Nation2       Oligarchy
# 17   Bezantur       Thay              137683      NaN             NaN
# 6    Bezantur       Thay              135864  Nation1       Oligarchy
# 13  Calimport  Calimshan              195600      NaN             NaN
#
#    Typical Cause of Death Wizarding School  Known Treasure Value  \
# 19                    NaN              NaN                   NaN
# 8                Accident              Yes          1,910,681.00
# 17                    NaN              NaN                   NaN
# 6                 Disease               No          2,954,109.00
# 13                    NaN              NaN                   NaN
#
#     Rumored Treasure Value  Dragon Sightings  ...  \
# 19                     NaN               NaN  ...
# ...

# %%
num_cities = df.shape[0]

species_age_ranges = {
            "Humans": [1, 100],
            "Halflings": [1, 150],
            "Orcs": [1, 50],
            "Elves": [1, 750],
            "Dwarves": [1, 350],
            "Gnomes": [300, 500]
        }

# Adjusting Danger Level
df['Danger Level'] = (
    df['Dragon Sightings']
    + df['Political Climate']
    + df['Magical Climate']
    + df['Likelihood of Getting Cursed']
    + df['Tax Rate']
    + df['Average Debt by Household']
    + df['Rumored Treasure Value']
    + df['Openness to Strangers'].apply(lambda x: 10 if x <= 2.5 or x >= 7.5 else 0)
).astype(int)

# Increase "Danger Level" if Orcs are present
df.loc[df['Percentage of population Orcs'] > 0, 'Danger Level'] += 1

# Decrease "Danger Level" if Elves are present
df.loc[df['Percentage of population Elves'] > 0, 'Danger Level'] -= 1

# Adjusting Danger Level based on the presence of Orcs and Elves
df['Danger Level'] = df.apply(lambda row: np.random.randint(1, 11)
                                          + (3 if row['Percentage of population Orcs'] > 0 else 0)
                                          - (2 if row['Percentage of population Elves'] > 0 else 0), axis=1)

# Adjusting Openness to Strangers
df['Openness to Strangers'] = df.apply(lambda row: np.random.randint(0, 11)
                                                   - (3 if row['Percentage of population Elves'] > 0
                                                       or row['Percentage of population Orcs'] > 0 else 0), axis=1)

# Adjusting Magical Climate
df['Magical Climate'] = df.apply(lambda row: row['Magical Climate']
                                             + (row['Percentage of population Elves'] / 100 * 2)
                                             + (row['Dragon Sightings'] / 10)
                                             + row['Number of Active Wizards'], axis=1)

# Pre-calculation of sum values
grouped = df.groupby('Region')
region_gold_mapping = grouped[['Active Economy (Gold)', 'Hidden Economy (Gold)']].sum(numeric_only=True).sum(axis=1)
df['Total Gold in Region'] = df['Region'].map(region_gold_mapping)

# Main DataFrame Manipulations
df['Dragon Sightings'] = df.apply(calculate_dragon_sightings, axis=1)
df['Dragon Sightings'] = ((df['Dragon Sightings'] - df['Dragon Sightings'].min()) /
                          (df['Dragon Sightings'].max() - df['Dragon Sightings'].min()) * 50).astype(int)

df['Average Age of Population'] = df.apply(lambda row: calculate_average_age(row, species_age_ranges), axis=1)
df['Average Age of Population'] -= df['Danger Level'] * 0.5
df['Average Age of Population'] = df['Average Age of Population'].clip(lower=1)

df['Hidden Economy (Gold)'] = df['Number of Nobility'] * 1e4
df['Openness to Strangers'] = df.apply(calculate_openness_to_strangers, axis=1)

# Adjusting population distribution for specific species across cities
def adjust_population_distribution(df, species, percentage, city_count):
    total_population = df['Population of City'].sum()
    target_population = int(total_population * (percentage / 100))
    selected_cities = df.sample(city_count)
    each_city_population = target_population // city_count
    for i, city in selected_cities.iterrows():
        df.at[i, f'Percentage of population {species}'] = (each_city_population / city['Population of City']) * 100

# Adjusting Economy Distribution
total_active_economy = np.sum(df['Active Economy (Gold)'])
top_10_cities_active_economy = total_active_economy * 0.50
next_100_cities_active_economy = total_active_economy * 0.25
remaining_cities_active_economy = total_active_economy * 0.25

# Known Treasure and Rumored Treasure Calculations
df['Known Treasure'] = df['Active Economy (Gold)'] * 0.50
df['Rumored Treasure'] = (df['Active Economy (Gold)'] * 0.50) + df['Hidden Economy (Gold)']

# Adjusting Political Climate and Fate Ranking
df['Wizarding School'] = np.random.choice(['yes', 'no'], num_cities)
df['Number of Homeowners'] = (df['Population of City'] * np.random.uniform(0.5, 0.7)).astype(int)
df['Average Rent'] = np.random.uniform(500, 2000, num_cities)
df['Average Age of Population'] = np.random.uniform(25, 70, num_cities)
df['Known Treasure Value'] = np.random.uniform(0, 1e6, num_cities)

# Adjust the tax rate based on the number of nobility
df['Tax Rate'] = df.apply(lambda row: 0 if row['Number of Nobility'] == 0 else row['Tax Rate'], axis=1)

# (You need to define 'Average Debt by Household' and 'Rumored Treasure Value' before using them in the next formula)
df['Political Climate'] = (df['Tax Rate'] + df['Number of Homeowners']/df['Population of City'] +
                              df['Average Rent']/2000 + df['Average Debt by Household']/1e4 +
                              df['Average Age of Population']/70 + df['Hidden Economy (Gold)']/1e6 +
                              df['Known Treasure Value']/1e6 + df['Rumored Treasure Value']/1e6) / 8

df['Fate ranking'] = (df['Rumored Treasure Value'] / 1e6) + np.where(df['Wizarding School'] == 'yes', 1, 0) + df['Political Climate']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 409 entries, 234 to 293
# Data columns (total 51 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   City                                409 non-null    object
#  1   Region                              409 non-null    object
#  2   Nation                              409 non-null    object
#  3   Government Type                     409 non-null    object
#  4   Population of City                  409 non-null    int64
#  5   Typical Cause of Death              409 non-null    object
#  6   Wizarding School                    409 non-null    object
#  7   Known Treasure Value                409 non-null    float64
#  8   Rumored Treasure Value              409 non-null    int64
#  9   Dragon Sightings                    409 non-null    int64
#  10  Tax Rate                            409 non-null    int64
# ...

# %%
# Save the DataFrame to Excel
df.to_excel(file_path, index=False)

# Confirm that the file has been saved
print(f"DataFrame saved to {file_path}")
# Out:
# DataFrame saved to /content/drive/MyDrive/Colab Notebooks/DnD/fictional_data.xlsx

# %%
# Read the xlsx file
df = pd.read_excel(file_path)

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 409 entries, 0 to 408
# Data columns (total 45 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   City                                409 non-null    object
#  1   Region                              409 non-null    object
#  2   Nation                              409 non-null    object
#  3   Government Type                     409 non-null    object
#  4   Population of City                  409 non-null    int64
#  5   Typical Cause of Death              409 non-null    object
#  6   Wizarding School                    409 non-null    object
#  7   Known Treasure Value                409 non-null    float64
#  8   Rumored Treasure Value              409 non-null    int64
#  9   Dragon Sightings                    409 non-null    int64
#  10  Tax Rate                            409 non-null    int64
# ...

# %%
df.head(50)
# Out:
#                                City   Region   Nation Government Type  \
# 234                       Abriymoch  Region1  Nation1       Democracy
# 176                           Aelor  Region1  Nation1        Monarchy
# 215                        Ageadren  Region1  Nation2       Theocracy
# 312                         Airspur  Region1  Nation1       Democracy
# 214                          Akanax  Region1  Nation2       Theocracy
# 161                         Akkaido  Region1  Nation2       Democracy
# 334                       Al-Anwahr  Region2  Nation1       Democracy
# 17                          Alashan  Region1  Nation1        Monarchy
# 376                       Almraiven  Region1  Nation2       Oligarchy
# 14                       Ammathluir  Region2  Nation2       Democracy
# 297                       Ammathtar  Region1  Nation2       Theocracy
# 375                       Anaxadren  Region2  Nation2        Monarchy
# ...

# %%
# Save the updated DataFrame back to the Excel file
df.to_excel('/content/drive/MyDrive/Colab Notebooks/DnD/fictional_data.xlsx', index=False)

# %%
# Step 3: Setting Tax Rate and Number of Nobility
df['# of Nobility'] = (df['City Population'] * np.random.uniform(0.01, 0.03)).astype(int)
df['Tax Rate'] = np.random.uniform(0.1, 0.3, cities) + (df['# of Nobility'] / df['City Population'])

# Step 4: Calculating Danger Level
df['Dragon Sightings'] = np.random.randint(0, 100, cities)
df['Political Climate'] = np.random.uniform(0, 1, cities)
df['Magical Climate'] = np.random.uniform(0, 1, cities)
df['Openness to Strangers'] = np.random.uniform(0, 1, cities)
df['Average Debt by Household'] = np.random.uniform(0, 1e4, cities)
df['Rumored Treasure Value'] = np.random.uniform(0, 1e6, cities)

bottom_quartile = df['Openness to Strangers'].quantile(0.25)
top_quartile = df['Openness to Strangers'].quantile(0.75)
openness_score = np.where(df['Openness to Strangers'] < bottom_quartile, 1,
                np.where(df['Openness to Strangers'] > top_quartile, 1, 0))

df['Likelihood of Getting Cursed'] = df['Magical Climate'] + openness_score
df['Danger Level'] = (df['Dragon Sightings'] + df['Political Climate'] +
                             df['Magical Climate'] + df['Likelihood of Getting Cursed'] +
                             df['Tax Rate'] + df['Average Debt by Household'] +
                             df['Rumored Treasure Value'] + openness_score) / 8

# Step 5: Setting Economic Factors
total_economy = np.random.uniform(80e6, 100e6)
df['Active Economy (Gold)'] = (np.random.uniform(0.4, 0.6, cities) * (df['City Population'] / total_population) * total_economy).astype(int)
df['Hidden Economy (Gold)'] = ((df['City Population'] / total_population) * total_economy - df['Active Economy (Gold)']).astype(int)

# Step 6: Setting Population Count for Nobility and Peasants
df['# of Peasants'] = (df['City Population'] * np.random.uniform(0.8, 0.9)).astype(int)

# Step 7: Configuring Fate Ranking
df['Wizarding School'] = np.random.choice(['yes', 'no'], cities)
df['Fate ranking'] = (df['Rumored Treasure Value'] / 1e6) + np.where(df['Wizarding School'] == 'yes', 1, 0)

# Print first few rows to check
print(df.head())
# Out:
#    City Population  Humans  Halflings  Dwarves  Elves  Orcs  Gnomes  \
# 0           211446  189768      11453     7622   5469  4244    3223
# 1           132049  117203       7846     4970   3219  3942    2361
# 2           102787   89566       5454     4031   2171  2598    1938
# 3           156526  126051       8041     5519   4484  3406    2897
# 4           207238  184331      12275     7835   5071  6053    3857
#
#    # of Nobility  Tax Rate  Dragon Sightings  ...  Openness to Strangers  \
# 0           2633  0.292279                77  ...               0.453717
# 1           1644  0.155011                19  ...               0.918264
# 2           1280  0.157687                25  ...               0.514864
# 3           1949  0.291992                38  ...               0.921383
# 4           2581  0.121567                97  ...               0.653692
#
#    Average Debt by Household  Rumored Treasure Value  \
# 0                4605.786974           135209.679497
# ...

# %%
# Step 9: Setting Political Climate
df['# Homeowners'] = (df['City Population'] * np.random.uniform(0.5, 0.7)).astype(int)
df['Average Rent'] = np.random.uniform(500, 2000, cities)
df['Average Age of Population'] = np.random.uniform(25, 70, cities)
df['Known Treasure Value'] = np.random.uniform(0, 1e6, cities)

df['Political Climate'] = (df['Tax Rate'] + df['# Homeowners']/df['City Population'] +
                                  df['Average Rent']/2000 + df['Average Debt by Household']/1e4 +
                                  df['Average Age of Population']/70 + df['Hidden Economy (Gold)']/1e6 +
                                  df['Known Treasure Value']/1e6 + df['Rumored Treasure Value']/1e6) / 8

# Step 10: Adjusting Fate Ranking
df['Fate ranking'] = (df['Rumored Treasure Value'] / 1e6) + np.where(df['Wizarding School'] == 'yes', 1, 0) + df['Political Climate']

# Step 11: Making Dataset Generation Replicable
def generate_dataset(seed=42):
    np.random.seed(seed)
    # ... (insert all the previous code that generates the data here)
    return df

# Generate a new dataset with a different seed each time to get a slightly different dataset
new_dataset = generate_dataset(seed=45)
print(new_dataset.head())

# You can use the generate_dataset function to create new datasets with minor variations each time
# Out:
#    City Population  Humans  Halflings  Dwarves  Elves  Orcs  Gnomes  \
# 0           211446  189768      11453     7622   5469  4244    3223
# 1           132049  117203       7846     4970   3219  3942    2361
# 2           102787   89566       5454     4031   2171  2598    1938
# 3           156526  126051       8041     5519   4484  3406    2897
# 4           207238  184331      12275     7835   5071  6053    3857
#
#    # of Nobility  Tax Rate  Dragon Sightings  ...  Danger Level  \
# 0           2633  0.292279                77  ...  17486.726748
# 1           1644  0.155011                19  ...  84428.834098
# 2           1280  0.157687                25  ...  25978.069289
# 3           1949  0.291992                38  ...  74876.358921
# 4           2581  0.121567                97  ...  20239.987652
#
#    Active Economy (Gold)  Hidden Economy (Gold)  # of Peasants  \
# 0                 129080                 160374         180474
# ...

# %%
df.head()
# Out:
#                   City   Region   Nation  Population of City Government  \
# 0            Abriymoch  Region2  Nation2               15922  Oligarchy
# 1                Aelor  Region2  Nation3               12583  Oligarchy
# 2             Ageadren  Region3  Nation2               84272  Oligarchy
# 3              Airspur  Region2  Nation3               50224  Oligarchy
# 4  Airspur (Chessenta)  Region1  Nation3               17081  Oligarchy
#
#    Percentage of population Humans  Percentage of population Halflings  \
# 0                        92.890664                            7.904120
# 1                        76.311884                            1.607618
# 2                        12.111212                           54.610246
# 3                        85.766203                           73.721184
# 4                         9.291475                           49.656559
#
#    Percentage of population Orcs  Percentage of population Elves  \
# ...

# %%
# Save the updated DataFrame back to the Excel file
df.to_excel('/content/drive/MyDrive/Colab Notebooks/DnD/fictional_data.xlsx', index=False)

# %%
# Step 1: Update Percentage Columns
percentage_columns = [
    'Percentage of population Humans',
    'Percentage of population Halflings',
    'Percentage of population Dwarves',
    'Percentage of population Elves',
    'Percentage of population Orcs',
    'Percentage of population Gnomes'
]

for col in percentage_columns:
    df[col] = df[col].round(2)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Percentage of population Humans'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
# Step 2: Adjust Danger Level

# Convert "Danger Level" to an integer between 1 and 10
df['Danger Level'] = (df['Dragon Sightings'] + df['Political Climate'] + df['Magical Climate'] + df['Likelihood of Getting Cursed'] + df['Tax Rate'] + df['Average Debt by Household'] + df['Rumored Treasure Value'] + df['Openness to Strangers'].apply(lambda x: 10 if x <= 2.5 or x >= 7.5 else 0)).astype(int)

# We normalize the "Danger Level" to be between 1 and 10
df['Danger Level'] = ((df['Danger Level'] - df['Danger Level'].min()) / (df['Danger Level'].max() - df['Danger Level'].min()) * 9 + 1).astype(int)

# Increase "Danger Level" if Orcs are present
df.loc[df['Percentage of population Orcs'] > 0, 'Danger Level'] += 1

# Decrease "Danger Level" if Elves are present
df.loc[df['Percentage of population Elves'] > 0, 'Danger Level'] -= 1

# Ensure "Danger Level" remains within the range 1-10
df['Danger Level'] = df['Danger Level'].clip(1, 10)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Percentage of population Orcs'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
# Step 3: Modify Dragon Sightings

# First, we'll create a mapping of the total gold per region
region_gold_mapping = df.groupby('Region')['Active Economy (Gold)', 'Hidden Economy (Gold)'].sum().sum(axis=1)

# Next, we'll adjust the Dragon Sightings based on the total gold in the region and the Fate ranking of the city
df['Dragon Sightings'] = df.apply(lambda row: (row['Fate ranking'] * (region_gold_mapping[row['Region']] / 1e6)), axis=1)

# We'll then normalize this to be a number between 0 and 50
df['Dragon Sightings'] = ((df['Dragon Sightings'] - df['Dragon Sightings'].min()) / (df['Dragon Sightings'].max() - df['Dragon Sightings'].min()) * 50).astype(int)

# Making sure "Dragon Sightings" does not exceed 50
df['Dragon Sightings'] = df['Dragon Sightings'].clip(0, 50)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-23-955dbff3a42c> in <cell line: 4>()
#       2
#       3 # First, we'll create a mapping of the total gold per region
# ----> 4 region_gold_mapping = city_data.groupby('Region')['Active Economy (Gold)', 'Hidden Economy (Gold)'].sum().sum(axis=1)
#       5
#       6 # Next, we'll adjust the Dragon Sightings based on the total gold in the region and the Fate ranking of the city
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    8400         axis = self._get_axis_number(axis)
#    8401
# -> 8402         return DataFrameGroupBy(
#    8403             obj=self,
#    8404             keys=by,
#
# ...

# %%
# Step 4: Determine Average Age of Population

# First, we'll define a function to calculate the average age based on the population percentages and the species' age ranges
def calculate_average_age(row):
    species_age_ranges = {
        "Humans": [1, 100],
        "Dwarves": [1, 350],
        "Elves": [1, 750],
        "Gnomes": [300, 500],
        "Halflings": [1, 150],
        "Orcs": [1, 50]
    }

    total_population = row['Population of City']
    weighted_ages = sum([(row[f'Percentage of population {species}'] / 100) * (sum(species_age_ranges[species]) / 2) * total_population for species in species_age_ranges])

    return weighted_ages / total_population

# Now, we'll apply this function to determine the average age of population
df['Average Age of Population'] = df.apply(calculate_average_age, axis=1)

# Considering the effect of "Danger Level" on the average age
df['Average Age of Population'] = df['Average Age of Population'] - (df['Danger Level'] * 0.5)

# Ensuring the average age doesn't fall below the minimum possible age
df['Average Age of Population'] = df['Average Age of Population'].clip(1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Population of City'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
import numpy as np

# Adjusting population distribution for specific species across cities
def adjust_population_distribution(df, species, percentage, city_count):
    total_population = df['Population of City'].sum()
    target_population = int(total_population * (percentage / 100))
    selected_cities = df.sample(city_count)
    each_city_population = target_population // city_count
    for i, city in selected_cities.iterrows():
        df.at[i, f'Percentage of population {species}'] = (each_city_population / city['Population of City']) * 100

# Adjusting the population distribution
adjust_population_distribution(df, "Gnomes", 99, 2)
adjust_population_distribution(df, "Dwarves", 80, 4)
adjust_population_distribution(df, "Elves", 95, 5)
adjust_population_distribution(df, "Orcs", 99, 1)

# Adjusting Dragon Sightings
df['Dragon Sightings'] = (df['Region'].map(df.groupby('Region')['Fate ranking'].sum() + df.groupby('Region')['Active Economy (Gold)'].sum()) / 1e6).clip(0, 50)

# Adjusting Danger Level
df['Danger Level'] = df.apply(lambda row: np.random.randint(1, 11) + (3 if row['Percentage of population Orcs'] > 0 else 0) - (2 if row['Percentage of population Elves'] > 0 else 0), axis=1)

# Adjusting Openness to Strangers
df['Openness to Strangers'] = df.apply(lambda row: np.random.randint(0, 11) - (3 if row['Percentage of population Elves'] > 0 or row['Percentage of population Orcs'] > 0 else 0), axis=1)

# Adjusting Magical Climate
df['Magical Climate'] = df.apply(lambda row: row['Magical Climate'] + (row['Percentage of population Elves'] / 100 * 2) + (row['Dragon Sightings'] / 10) + row['Number of Active Wizards'], axis=1)

# Adjusting Hidden Economy based on the number of nobility
df['Hidden Economy (Gold)'] = df.apply(lambda row: row['Hidden Economy (Gold)'] * (1 + (row['# of Nobility'] / row['Population of City']) * 100), axis=1)

# Ensuring Percentage values are rounded to 2 decimal places
percentage_columns = [col for col in df.columns if 'Percentage' in col]
df[percentage_columns] = df[percentage_columns].round(2)

# Making sure Openness to Strangers is between 0 and 10
df['Openness to Strangers'] = df['Openness to Strangers'].clip(0, 10)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Population of City'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
def calculate_average_age(row):
    human_percentage = row['Percentage of population Humans']
    dwarf_percentage = row['Percentage of population Dwarves']
    elf_percentage = row['Percentage of population Elves']
    gnome_percentage = row['Percentage of population Gnomes']
    halfling_percentage = row['Percentage of population Halflings']
    orc_percentage = row['Percentage of population Orcs']

    # Getting the random average age for each species
    human_avg_age = np.random.uniform(1, 100, 1)[0]
    dwarf_avg_age = np.random.uniform(1, 350, 1)[0]
    elf_avg_age = np.random.uniform(1, 750, 1)[0]
    gnome_avg_age = np.random.uniform(300, 500, 1)[0]
    halfling_avg_age = np.random.uniform(1, 150, 1)[0]
    orc_avg_age = np.random.uniform(1, 50, 1)[0]

    # Calculating the average age of the population
    average_age = (
        (human_avg_age * human_percentage) +
        (dwarf_avg_age * dwarf_percentage) +
        (elf_avg_age * elf_percentage) +
        (gnome_avg_age * gnome_percentage) +
        (halfling_avg_age * halfling_percentage) +
        (orc_avg_age * orc_percentage)
    ) / 100

    return average_age

# Setting the average age of population
df['Average Age of Population'] = df.apply(calculate_average_age, axis=1)

# Setting the number of active wizards randomly between 0 and 20
df['Number of Active Wizards'] = np.random.randint(0, 21, df.shape[0])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Percentage of population Humans'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
def calculate_dragon_sightings(row):
    # The dragon sightings are influenced by the total gold in a region and the fate ranking of the city
    region_gold = df[df['Region'] == row['Region']]['Active Economy (Gold)'].sum() + df[df['Region'] == row['Region']]['Hidden Economy (Gold)'].sum()
    max_sightings = min(50, row['Fate ranking'] + region_gold // 1e6)
    return np.random.randint(0, max_sightings+1)

def adjust_danger_level(row):
    # Adjusting danger level based on the presence of Orcs and Elves
    danger_level = row['Danger Level']
    if row['Percentage of population Orcs'] > 0:
        danger_level += 1
    if row['Percentage of population Elves'] > 0:
        danger_level -= 1
    return min(max(1, danger_level), 10)

def calculate_magical_climate(row):
    # Adjusting magical climate based on dragon sightings and the number of active wizards
    return row['Dragon Sightings'] * 0.1 + row['Number of Active Wizards'] * 0.5

def calculate_openness_to_strangers(row):
    # Adjusting openness to strangers based on the presence of Elves or Orcs
    openness = row['Openness to Strangers']
    if row['Percentage of population Elves'] > 0 or row['Percentage of population Orcs'] > 0:
        openness -= 2
    return min(max(0, openness), 10)

# Applying the functions
df['Dragon Sightings'] = df.apply(calculate_dragon_sightings, axis=1)
df['Danger Level'] = df.apply(adjust_danger_level, axis=1)
df['Magical Climate'] = df.apply(calculate_magical_climate, axis=1)
df['Openness to Strangers'] = df.apply(calculate_openness_to_strangers, axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Region'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
# Step 8.1: Adjusting Population Distribution
# Define the cities where majority of the specific species will reside
gnome_cities = np.random.choice(df['City'], size=2, replace=False)
dwarf_cities = np.random.choice(df['City'], size=4, replace=False)
elf_cities = np.random.choice(df['City'], size=5, replace=False)
orc_city = np.random.choice(df['City'], size=1, replace=False)

# Define functions to adjust the population percentages for Gnomes, Dwarves, Elves, and Orcs
def adjust_gnome_population(row):
    if row['City'] in gnome_cities:
        return np.random.uniform(40, 50)
    return np.random.uniform(0, 0.1)

def adjust_dwarf_population(row):
    if row['City'] in dwarf_cities:
        return np.random.uniform(15, 25)
    return np.random.uniform(0, 1)

def adjust_elf_population(row):
    if row['City'] in elf_cities:
        return np.random.uniform(15, 20)
    return np.random.uniform(0, 1)

def adjust_orc_population(row):
    if row['City'] == orc_city:
        return np.random.uniform(90, 99)
    return np.random.uniform(0, 1)

# Apply the functions to adjust the population distribution
df['Percentage of population Gnomes'] = df.apply(adjust_gnome_population, axis=1)
df['Percentage of population Dwarves'] = df.apply(adjust_dwarf_population, axis=1)
df['Percentage of population Elves'] = df.apply(adjust_elf_population, axis=1)
df['Percentage of population Orcs'] = df.apply(adjust_orc_population, axis=1)

# Step 8.2: Calculating Average Age of Population
# Define a function to calculate the average age based on the species population percentages and danger level
def calculate_average_age(row):
    human_age = np.random.uniform(1, 100)
    dwarf_age = np.random.uniform(1, 350)
    elf_age = np.random.uniform(1, 750)
    gnome_age = np.random.uniform(300, 500)
    halfling_age = np.random.uniform(1, 150)
    orc_age = np.random.uniform(1, 50)
    total_population = row['Total Population']

    avg_age = ((human_age * row['Percentage of population Humans'] +
                dwarf_age * row['Percentage of population Dwarves'] +
                elf_age * row['Percentage of population Elves'] +
                gnome_age * row['Percentage of population Gnomes'] +
                halfling_age * row['Percentage of population Halflings'] +
                orc_age * row['Percentage of population Orcs']) / 100)

    return avg_age - (row['Danger Level'] / 10)

# Apply the function to calculate the average age
df['Average Age of Population'] = df.apply(calculate_average_age, axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'City'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
# Step 9.1: Calculate Dragon Sightings based on total gold in a region and the Fate ranking of the city
df['Dragon Sightings'] = (df['Total Gold in Region'] / 1e6) + df['Fate ranking']
df['Dragon Sightings'] = df['Dragon Sightings'].apply(lambda x: min(x, 50))

# Step 9.2: Modify Danger Level
def calculate_danger_level(row):
    danger_level = row['Danger Level']
    if row['Percentage of population Orcs'] > 0:
        danger_level += 1
    if row['Percentage of population Elves'] > 0:
        danger_level -= 1
    return min(max(int(danger_level), 1), 10)
df['Danger Level'] = df.apply(calculate_danger_level, axis=1)

# Step 9.3: Modify Magical Climate
def calculate_magical_climate(row):
    magical_climate = row['Magical Climate']
    if row['Percentage of population Elves'] > 0:
        magical_climate += 1
    magical_climate += row['Dragon Sightings'] / 10
    magical_climate += row['Number of Active Wizards'] / 2
    return min(max(int(magical_climate), 1), 10)
df['Magical Climate'] = df.apply(calculate_magical_climate, axis=1)

# Step 9.4: Modify Openness to Strangers
def calculate_openness_to_strangers(row):
    openness = row['Openness to Strangers']
    if row['Percentage of population Elves'] > 0 or row['Percentage of population Orcs'] > 0:
        openness -= 2
    return min(max(int(openness), 0), 10)
df['Openness to Strangers'] = df.apply(calculate_openness_to_strangers, axis=1)

# Step 9.5: Modify Hidden Economy
df['Hidden Economy'] = df['# of Nobility'] * 1e4

# %%
aglarond_data = {
    'region': 'Aglarond',
    'ruler': 'The Simbul',
    'capital': {
        'name': 'Velprintalar',
        'population': 66044,
    },
    'settlements': [
        {'name': 'Corth', 'population': 500},
        {'name': 'Dahst', 'population': 300},
        {'name': 'Dlusk', 'population': 1000},
        {'name': 'Emmech', 'population': 7620},
        {'name': 'Findar', 'population': 300},
        {'name': 'Furthinghome', 'population': 40643},
        {'name': 'Glarondar', 'population': 5489},
        {'name': 'Halendos', 'population': 200},
        {'name': 'Ingdal’s Arm', 'population': 1000},
        {'name': 'Mesring', 'population': 1000},
        {'name': 'Orithar', 'population': 500},
        {'name': 'Osker', 'population': 700},
        {'name': 'Relkath’s Foot', 'population': 5080},
        {'name': 'Thayguard', 'population': 5000},
        {'name': 'Urst', 'population': 1000},
        {'name': 'Urve', 'population': 500},
    ],
    'population': {
        'total': 1270080,
        'breakdown': {
            'human': '64%',
            'half-elf': '30%',
            'elf': '5%',
            'miscellaneous': '1%',
        },
        'density': {
            'miles_squared': 19.57,
            'kilometres_squared': 7.56,
        }
    },
    'total_area': {
        'miles_squared': 64902,
        'kilometres_squared': 168095.41,
    },
    'military': {
        'standing': 6000,
        'full_mobilisation': 30000,
        'note': 'for a brief period',
    },
    'languages': ['Aglarondan', 'Common', 'Elven (Yuir)'],
    'religion': [
        'Chauntea',
        'the Seldarine (elven pantheon)',
        'Selûne',
        'Umberlee',
        'Valkur',
        'the Yuir (vanished elven sub-pantheon, consisting of Relkath of the Infinite Branches, Zandilar the Dancer and Elikarashae)',
    ],
    'economy': {
        'exports': ['lumber', 'grain', 'gems', 'copper', 'wine'],
        'imports': ['glass', 'iron', 'textiles', 'produce'],
    },
    'sources': [
        'Spellbound - Anthony Pryor, 1995',
        'Unapproachable East - Richard Baker, Matt Forbeck & Sean K. Reynolds, 2003',
    ],
}

# %%
amn_data = {
    'region': 'Amn',
    'ruler': 'The Council of Six',
    'capital': {
        'name': 'Athkatla',
        'population': 118304,
    },
    'settlements': [
        {'name': 'Amnwater', 'population': 7500},
        {'name': 'Citadel Amnur', 'population': 700},
        {'name': 'Citadel Rashturl', 'population': 700},
        {'name': 'Coryllvol'},
        {'name': 'Crimmor', 'population': 35491},
        {'name': 'Dark Redoubt', 'population': 300},
        {'name': 'Edive', 'population': 200},
        {'name': 'Esford'},
        {'name': 'Eshpurta', 'population': 24252},
        {'name': 'Esmeltaran', 'population': 21000},
        {'name': 'Gambiton'},
        {'name': 'Goldspires', 'population': 1200},
        {'name': 'Hillfort Ishla', 'population': 316},
        {'name': 'Hillfort Keshla', 'population': 435},
        {'name': 'Hillfort Torbold', 'population': 316},
        {'name': 'Ideepton', 'population': 200},
        {'name': 'Imnescar', 'population': 6000},
        {'name': 'Keczulla', 'population': 47322},
        {'name': 'Minsor Vale', 'population': 200},
        {'name': 'Murann', 'population': 43773, 'note': 'under ogre occupation'},
        {'name': 'Nashkel', 'population': 3000},
        {'name': 'Purskul', 'population': 27210},
        {'name': 'Quarrelshigh', 'population': 500},
        {'name': 'Riatavin', 'population': 125000, 'note': 'in rebellion'},
        {'name': 'Scimitar'},
        {'name': 'Shatar', 'population': 200},
        {'name': 'Shepherdston'},
        {'name': 'Trademeet', 'population': 6000, 'note': 'under ogre occupation'},
        {'name': 'Trailstone', 'population': 700, 'note': 'in rebellion'},
        {'name': 'Zinner'}
    ],
    'population': {
        'total': 2963520,
        'breakdown': {
            'humans': '83%',
            'halflings': '15%',
            'half-orcs': '1%',
            'miscellaneous': '1%'
        },
        'density': {
            'miles_squared': 10.93,
            'kilometres_squared': 4.22
        }
    },
    'total_area': {
        'miles_squared': 271111,
        'kilometres_squared': 702174.27
    },
    'military': 'Varies (largely dependent on mercenary companies)',
    'languages': ['Chondathan', 'Common'],
    'religion': ['Bane', 'Chauntea', 'Cyric', 'Selûne', 'Sune', 'Waukeen'],
    'economy': {
        'exports': [
            'ale', 'amour', 'beer', 'caravan items (wagons, wheels)', 'gems',
            'gold', 'grain', 'horses', 'iron', 'jewellery', 'weapons'
        ],
        'imports': [
            'exotic goods (from Maztica)', 'magic items', 'mercenaries',
            'pearls', 'siege weapons'
        ]
    },
    'sources': [
        'Empires of the Sands - Scott Haring, 1988',
        'Lands of Intrigue - Steven E. Schend, 1997'
    ]
}

# %%
calimshan_data = {
    'region': 'Calimshan',
    'capital': {
        'name': 'Calimport',
        'population': {
            'total': 2000000,
            'citizens': 192795,
            'note': 'includes surrounds & slaves'
        }
    },
    'settlements': [
        {'name': 'Almraiven', 'population': 43652},
        {'name': 'Keltar', 'population': 24000},
        {'name': 'Manshaka', 'population': 37000},
        {'name': 'Memnon', 'population': 29101},
        {'name': 'Schamedar', 'population': 20000},
        {'name': 'Suldolphor', 'population': 143687},
        {'name': 'Teshburl', 'population': 21800},
        {'name': 'Volothamp', 'population': 36640, 'note': 'this figure does not include slaves'}
    ],
    'population': {
        'total': 5339520,
        'note': 'approx., population counts of slaves are highly unreliable',
        'density': {
            'miles_squared': 23.87,
            'kilometres_squared': 9.22
        }
    },
    'total_area': {
        'miles_squared': 223690,
        'kilometres_squared': 579354.44
    },
    'languages': ['Alzhedo', 'Common'],
    'religion': ['Anachtyr (Tyr)', 'Azuth', 'Bhaelros (Talos)', 'Ibrandul (Shar)', 'Ilmater', 'Shar', 'Sharess'],
    'economy': {
        'exports': [
            'armour', 'books', 'gems', 'jewellery', 'leather goods',
            'mercenaries', 'minor magic items', 'pearls', 'pottery',
            'rare herbs', 'rope', 'ships', 'silk', 'spices', 'weapons', 'wine'
        ],
        'imports': ['food', 'slaves', 'magic']
    },
    'sources': [
        'Empires of the Sands - Scott Haring, 1988',
        'Empires of the Shining Sea - Steven E. Schend, 1998',
        'Calimport - Steven E. Schend, 1998'
    ]
}

# %%
chessenta_data = {
    'region': 'Chessenta',
    'capital': {
        'name': 'Cimbar',
        'population': 110843,
        'status': 'disputed'
    },
    'settlements': [
        {'name': 'Airspur', 'population': 22282},
        {'name': 'Akanax', 'population': 24632},
        {'name': 'Erebos'},
        {'name': 'Gaj'},
        {'name': 'Heptios', 'population': 9000},
        {'name': 'Luthcheq', 'population': 61580},
        {'name': 'Maerduuth'},
        {'name': 'Mordulkin', 'population': 35000},
        {'name': 'Oslin'},
        {'name': 'Pandrik'},
        {'name': 'Rodanar', 'population': 5000},
        {'name': 'Saden', 'population': 900},
        {'name': 'Samnur'},
        {'name': 'Soolabax', 'population': 1800},
        {'name': 'Soorenar', 'population': 73896},
        {'name': 'Toreus'},
        {'name': 'Tulach'},
        {'name': 'Villon'}
    ],
    'population': {
        'total': 3386880,
        'density': {
            'miles_squared': 13.52,
            'kilometres_squared': 5.22
        },
        'composition': {
            'human': 82,
            'halfling': 6,
            'dwarf': 5,
            'half_orc': 4,
            'lizardfolk': 2
        }
    },
    'total_area': {
        'miles_squared': 250460,
        'kilometres_squared': 648688
    },
    'military': {
        'mercenary_companies': [
            {'name': 'Wraith of the Inner Sea'},
            {'name': 'the Renegades'},
            {'name': 'the Sailors of the Crimson Sea'},
            {'name': 'the Society of the Sword'}
        ]
    },
    'languages': ['Chessentan', 'Chondathan', 'Common', 'Untheric'],
    'religion': ['Anhur', 'Assuran (Hoar)', 'Azuth', 'Lathander', 'Red Knight', 'Tchazzar (Tiamat)', 'Waukeen'],
    'economy': {
        'exports': ['art', 'cattle', 'gold', 'grapes', 'olive oil', 'quality iron', 'silver', 'slaves', 'statues', 'weapons', 'wine'],
        'imports': ['cheese', 'glass', 'horses', 'magic weapons', 'mercenaries', 'perfume', 'pork', 'slaves']
    }
}

# %%
chondath_data = {
    'region': 'Chondath',
    'capital': {
        'name': 'Arrabar',
        'population': 61012
    },
    'settlements': [
        {'name': 'Iljak', 'population': 17432},
        {'name': 'Nun'},
        {'name': 'Orbesh'},
        {'name': 'Samra'},
        {'name': 'Shamph', 'population': 32685},
    ],
    'population': {
        'total': 1982880,
        'density': {
            'miles_squared': 44.24,
            'kilometres_squared': 17.08
        },
        'composition': {
            'human': 96,
            'elf': 2,
            'dwarf': 1,
            'misc': 1
        }
    },
    'total_area': {
        'miles_squared': 44819,
        'kilometres_squared': 116080.68
    },
    'military': {
        'mercenary_companies': [
            {'name': 'Order of the Sapphire Crescent'}
        ]
    },
    'languages': ['Chondathan', 'Common'],
    'religion': ['Helm', 'Lliira', 'Malar', 'Talos', 'Tempus', 'Waukeen'],
    'economy': {
        'exports': ['lumber', 'mercenaries', 'salt', 'spices'],
        'imports': ['metals']
    }
}

# %%
cormyr_data = {
    'region': 'Cormyr',
    'capital': {
        'name': 'Suzail',
        'population': {
            'city': 45009,
            'surrounds': 129000
        }
    },
    'settlements': [
        {'name': 'Arabel', 'population': 30606},
        {'name': 'Aunkspear'},
        {'name': 'Battlerise'},
        {'name': 'Besert'},
        {'name': 'Blustich'},
        {'name': 'Bogbrook', 'population': 800},
        {'name': 'Bospir'},
        {'name': 'Castle Crag', 'population': 505},
        {'name': 'Dawngleam', 'population': 800},
        {'name': 'Dhedluk', 'population': 936},
        {'name': 'Dreamer’s Rock'},
        {'name': 'Espar', 'population': 600},
        {'name': 'Eveningstar', 'population': 954},
        {'name': 'Ghars', 'population': 1200},
        {'name': 'Gladehap', 'population': 900},
        {'name': 'Gorthin'},
        {'name': 'Gray Oaks', 'population': 100},
        {'name': 'Halfhap', 'population': 2200},
        {'name': 'High Horn', 'population': 400},
        {'name': 'Hillmarch'},
        {'name': 'Hilp', 'population': 250},
        {'name': 'Hultail', 'population': 100},
        {'name': 'Immersea', 'population': 1170},
        {'name': 'Jester’s Green', 'site': True},
        {'name': 'Juniril'},
        {'name': 'Kallamarn'},
        {'name': 'Kirinwood'},
        {'name': 'Knightswood'},
        {'name': 'Marsark’s Grove'},
        {'name': 'Marsember', 'population': 36007},
        {'name': 'Minroe', 'population': 500},
        {'name': 'Monksblade', 'population': 300},
        {'name': 'Moonever', 'population': 800},
        {'name': 'Mouth O’ Gargoyles', 'population': 460},
        {'name': 'Nesmyth'},
        {'name': 'Ongul’s Water'},
        {'name': 'Redspring'},
        {'name': 'Smuggler’s Stone'},
        {'name': 'Stag Steads'},
        {'name': 'Sunset Hill', 'population': 1000},
        {'name': 'Thunderstone', 'population': 1800},
        {'name': 'Tilverton', 'population': 9002},
        {'name': 'Tyrluk', 'population': 200},
        {'name': 'Waymoot', 'population': 1980},
        {'name': 'Wheloon', 'population': 6661},
        {'name': 'Wormtower'},
        {'name': 'Yeoman Bridge'}
    ],
    'population': {
        'total': 1360800,
        'density': {
            'miles_squared': 12.09,
            'kilometres_squared': 4.67
        },
        'composition': {
            'human': 85,
            'half_elf': 10,
            'elf': 4,
            'misc': 1
        }
    },
    'total_area': {
        'miles_squared': 112569,
        'kilometres_squared': 291552.37
    },
    'military': {
        'purple_dragons': {
            'type': 'standing_army',
            'strength': 12000
        },
        'war_wizards_of_cormyr': {
            'strength': 200
        }
    },
    'languages': ['Chondathan', 'Common', 'Elven'],
    'religion': ['Chauntea', 'Deneir', 'Helm', 'Lathander', 'Lliira', 'Oghma', 'Malar', 'Milie', 'Selûne', 'Silvanus', 'Tempus', 'Tymora', 'Waukeen'],
    'economy': {
        'exports': ['Armor', 'carved ivory', 'cloth', 'coal', 'food', 'swords', 'timber'],
        'imports': ['Glass', 'ivory', 'spices']
    }
}

# %%
dambrath_data = {
    'region': 'Dambrath',
    'capital': {
        'name': 'Cathyr',
        'population': 42374
    },
    'settlements': [
        {'name': 'Ammathtar', 'population': 10000},
        {'name': 'Crimar', 'population': 'unknown'},
        {'name': 'Dannash', 'population': 'unknown'},
        {'name': 'Darmesh', 'population': 'unknown'},
        {'name': 'Dunfeld', 'population': 'unknown'},
        {'name': 'Farpost', 'population': 'unknown'},
        {'name': 'Guilmarl', 'population': 5000},
        {'name': 'Hazuth', 'population': 20000},
        {'name': 'Herath', 'population': 18000},
        {'name': 'Hethar', 'population': 5000},
        {'name': 'Luenath', 'population': 31000},
        {'name': 'Maarlith', 'population': 'unknown'},
        {'name': 'North Post', 'population': 'unknown'},
        {'name': 'Prastuil', 'population': 30000},
        {'name': 'Purl', 'population': 'unknown'},
        {'name': 'Timarl', 'population': 'unknown'},
        {'name': 'T’lindhet', 'population': 9000},
        {'name': 'Westbay', 'population': 'unknown'},
        {'name': 'Westwatch', 'population': 'unknown'}
    ],
    'population': {
        'total': 'unknown',
        'by_race': {
            'human': 'unknown',
            'drow': 'unknown',
            'others': 'unknown'
        }
    },
    'population_density': {
        'people_per_mile_squared': 'unknown',
        'people_per_km_squared': 'unknown'
    },
    'area': {
        'miles_squared': 363706,
        'kilometres_squared': 941994.22
    },
    'military': {
        'standing_army': '20,000+',
        'navy': 'unknown'
    },
    'languages': ['Dambrathan', 'Common', 'Undercommon', 'Drow'],
    'religion': ['Loviatar', 'Lolth', 'Eilistraee', 'Malar'],
    'exports': ['Horses', 'silver', 'pearls', 'wooden items', 'fruit', 'fish'],
    'imports': 'unknown'
}

# %%
damara_data = {
    'region': 'Damara',
    'capital': {
        'name': 'Heliogabalus',
        'population': 44111
    },
    'settlements': [
        {'name': 'Bloodstone Gate', 'population': 13233},
        {'name': 'Bloodstone Town', 'population': 7500},
        {'name': 'Brotha', 'population': 400},
        {'name': 'Cutrock', 'population': 'unknown'},
        {'name': 'Goliad', 'population': 900},
        {'name': 'Daleport', 'population': 125},
        {'name': 'Dunfee', 'population': 'unknown'},
        {'name': 'Helmsdale', 'population': 80},
        {'name': 'Hinterford', 'population': 'unknown'},
        {'name': 'Ironspur', 'population': 'unknown'},
        {'name': 'Kinbrace', 'population': 4500},
        {'name': 'Kinnery', 'population': 'unknown'},
        {'name': 'Merkurn', 'population': 'unknown'},
        {'name': 'Morovar', 'population': 4000},
        {'name': 'Newbelle', 'population': 'unknown'},
        {'name': 'Ostrav', 'population': 200},
        {'name': 'Portith', 'population': 1200},
        {'name': 'Praka', 'population': 11000},
        {'name': 'Ravensburg', 'population': 3500},
        {'name': 'Rolene', 'population': 'unknown'},
        {'name': 'Samek', 'population': 'unknown'},
        {'name': 'Steppenhall', 'population': 70},
        {'name': 'Sudrav', 'population': 600},
        {'name': 'Tellerth', 'population': 2300},
        {'name': 'Thimble', 'population': 'unknown'},
        {'name': 'Tokard', 'population': 'unknown'},
        {'name': 'Tomrav', 'population': 450},
        {'name': 'Trailsend', 'population': 14116},
        {'name': 'Valls', 'population': 1300},
        {'name': 'Virdin', 'population': 1500},
        {'name': 'Wassen', 'population': 250},
        {'name': 'Windless', 'population': 2500},
        {'name': 'Withermeet', 'population': 100},
        {'name': 'Zarach', 'population': 600}
    ],
    'population': 1321920,
    'population_distribution': {
        'human': 87,
        'dwarf': 6,
        'halfling': 4,
        'half-orc': 2,
        'misc': 1
    },
    'population_density': {
        'per_mile_sq': 7.38,
        'per_km_sq': 2.85
    },
    'area': {
        'miles_sq': 179042,
        'km_sq': 463716.51
    },
    'military': {
        'standing_army': 4000,
        'mercenary_companies': 'more'
    },
    'languages': ['Damaran', 'Common', 'Dwarven'],
    'religion': ['Ilmater', 'Silvanus', 'Tempus'],
    'exports': ['Gems', 'gold', 'iron', 'silver'],
    'imports': ['Food', 'livestock', 'wood']
}

# %%
durpar_data = {
    'region': 'Durpar',
    'ruler': 'Grand Nawab Kara Jeratma of the High Council of Durpar',
    'capital': {
        'name': 'Heldapan',
        'population': 50000,
    },
    'settlements': [
    {'name': 'Assur', 'population': 5000},
    {'name': 'Bralizzar', 'population': 500},
    {'name': 'Flyndagol', 'population': 'Unknown'},
    {'name': 'Huorm', 'population': 'Unknown'},
    {'name': 'Lastarr', 'population': 10000},
    {'name': 'Morvar', 'population': 20000},
    {'name': 'Ormpé', 'population': 4500},
    {'name': 'Orpher', 'population': 'Unknown'},
    {'name': 'Pharsul', 'population': 'Unknown'},
    {'name': 'Protain', 'population': 'Unknown'},
    {'name': 'Sandsrun', 'population': 'Unknown'},
    {'name': 'Seldazar', 'population': 'Unknown'},
    {'name': 'Sezilinta', 'population': 17000},
    {'name': 'Ssundyl', 'population': 'Unknown'},
    {'name': 'Turelve', 'population': 30000},
    {'name': 'Vaelan', 'population': 45000},
    {'name': 'Vurpar', 'population': 'Unknown'},
],
    'population': None,
    'area': {
        'miles_squared': 247574,
        'kilometres_squared': 641213.72,
    },
    'military': 'Mercenary companies, private militias',
    'languages': ['Durpari', 'Untheric', 'Common'],
    'religion': ['The Adama', 'Curna (Oghma)', 'Lucha (Selûne)', 'Torm', 'Zionil (Gond)', 'Waukeen'],
    'economy': {
        'exports': ['Fine cloths', 'coffee', 'field glass', 'grain', 'soap', 'spices'],
        'imports': [],  # No data for imports
    },
    'sources': [
        'The Shining South - Tom Prusa, 1993',
        'Shining South - Todd Gamble, 2004',
    ],
}

estagund_data = {
    'region': 'Estagund',
    'ruler': 'Rajah Ekripet Seltarir',
    'capital': {
        'name': 'Chavyondat',
        'population': 67489,
    },
    'settlements': [
        {'name': 'Kolapur', 'population': 'Unknown'},
        {'name': 'Ulara', 'population': 'Unknown'},
        {'name': 'Zabbasz', 'population': 'Unknown'},
    ],
    'population': {
        'total': 'Unknown',
        'breakdown': {
            'human': '81%',
            'halfling': '7%',
            'half-elf': '4%',
            'dwarf': '3%',
            'gnome': '2%',
            'half-orc': '2%',
            'miscellaneous': '1%',
        },
    },
    'area': {
        'miles_squared': 90807,
        'kilometres_squared': 235189,
    },
    'military': 'The Maquar',
    'languages': ['Durpari', 'Common'],
    'religion': ['The Adama', 'Curna (Oghma)', 'Lucha (Selûne)', 'Torm', 'Zionil (Gond)', 'Waukeen'],
    'economy': {
        'exports': [],  # No data for exports
        'imports': [],  # No data for imports
    },
    'sources': [
        'The Shining South - Tom Prusa, 1993',
        'Shining South - Todd Gamble, 2004',
    ],
}

var_the_golden_data = {
    'region': 'Var the Golden',
    'ruler': 'Supreme Potentate Anwir Duprestiskava',
    'capital': {
        'name': 'Pyratar',
        'population': 45000,
    },
    'settlements': [
        {'name': 'Des', 'population': 'Unknown'},
        {'name': 'Durgach', 'population': 'Unknown'},
        {'name': 'Gust', 'population': 'Unknown'},
        {'name': 'Myrmyr', 'population': 'Unknown'},
        {'name': 'Tannath', 'population': 'Unknown'},
        {'name': 'Zelpir', 'population': 'Unknown'},
    ],
    'population': 'Unknown',
    'area': {
        'miles_squared': 108730,
        'kilometres_squared': 281609.4,
    },
    'military': 'Private militias, priestly warrior orders, mercenaries',
    'languages': ['Durpari', 'Common'],
    'religion': ['The Adama', 'Curna (Oghma)', 'Lucha (Selûne)', 'Mask', 'Torm', 'Waukeen', 'Zionil (Gond)'],
    'economy': {
        'exports': ['Grain', 'wheat', 'foodstuffs'],
        'imports': [],  # No data for imports
    },
    'sources': [
        'The Shining South - Tom Prusa, 1993',
        'Shining South - Todd Gamble, 2004',
    ],
}

# %%
erlkazar_data = {
    'region': 'Erlkazar',
    'ruler': 'King Korox Morkann',
    'capital': {
        'name': 'Llorbauth',
        'population': 28000,
    },
    'settlements': [
        {'name': 'Carradoon', 'population': None},
        {'name': 'Duhlnarim', 'population': None},
        {'name': 'Five Spears Hold', 'population': None},
        {'name': 'Fort Blood', 'population': None},
        {'name': 'Furrowsrich', 'population': None},
        {'name': 'Golconda', 'population': None},
        {'name': 'Praskallest', 'population': None},
        {'name': 'Rivenshield', 'population': None},
        {'name': 'Shalane', 'population': None},
        {'name': 'Tibold', 'population': None},
    ],
    'population': {
        'total': None,
        'breakdown': {
            'dwarves': 'more than in Tethyr',
            'elves': 'almost as many as in Tethyr',
            'ogres': 320,
            'miscellaneous': None,
        },
        'density': {
            'miles_squared': None,
            'kilometres_squared': None,
        }
    },
    'total_area': {
        'miles_squared': 109198,
        'kilometres_squared': 282821.52,
    },
    'military': {
        'standing': None,
        'full_mobilisation': None,
        'note': 'comprises small militias and mercenary companies including Elestam’s Crusaders (currently retired) and the Shieldbreaker company',
    },
    'languages': ['Chondathan', 'Common', 'Dwarven'],
    'religion': [
        'Azuth',
        'Deneir',
        'Malar',
        'Mystra',
    ],
    'economy': {
        'exports': None,
        'imports': None,
    },
    'sources': [
        'Lands of Intrigue - Steven Schend, 1997',
    ],
}

# %%
evereska_data = {
    'region': 'Evereska',
    'ruler': 'High Lord Erlan Duirsar and the Council of Hill Elders',
    'capital': {
        'name': 'Evermeet',
        'population': None,  # Population data for the capital is missing
    },
    'settlements': [
        {'name': 'Greyhome', 'population': None},
        {'name': 'Greyshield', 'population': None},
        {'name': 'the Halfway Inn', 'population': None},
    ],
    'population': {
        'total': 21051,
        'breakdown': {
            'elf': '99%',
            'miscellaneous': '1%',
        },
        'density': {
            'miles_squared': 1.42,
            'kilometres_squared': 0.56,
        }
    },
    'total_area': {
        'miles_squared': 14736,
        'kilometres_squared': 38166.065,
    },
    'military': {
        'standing': 'The Army of Evereska',
        'divisions': [
            'the Long Watch',
            'the Swords of Evereska',
            'the Cold Hand',
            'the Vale Guard',
            'the Tomb Guard',
            'the Feather Cavalry'
        ],
    },
    'languages': ['Common', 'Elven'],
    'religion': ['The Seldarine'],
    'economy': {
        'exports': ['paintings', 'statues', 'wine', 'wood carvings', 'elven spirits'],
        'imports': ['metal ore'],
    },
    'sources': [
        'The Return of the Archwizards trilogy - Troy Denning, 2001-02',
    ],
}

# %%
evermeet_data = {
    'region': 'Evermeet',
    'ruler': [
        'Queen Amlaruil Moonflower',
        'the Council of Matrons',
        'the Queen’s High Council'
    ],
    'capital': {
        'name': 'Leuthilspar',
        'population': 50269,
    },
    'settlements': [
        {'name': 'Drelagara', 'population': None},
        {'name': 'Elion', 'population': 1500},
        {'name': 'Erial', 'population': None},
        {'name': 'Iumathiashae', 'population': None},
        {'name': 'Nimlith', 'population': 1000},
        {'name': 'Ruith', 'population': 10000},
        {'name': 'Sumbrar', 'population': None},
        {'name': 'Taltempla', 'population': None},
    ],
    'population': {
        'total': 1658880,
        'breakdown': {
            'elves': '99%',
            'miscellaneous': '1%',
        },
        'density': {
            'miles_squared': 18.43,
            'kilometres_squared': 7.12,
        }
    },
    'total_area': {
        'miles_squared': 89006,
        'kilometres_squared': 230524,
    },
    'military': {
        'divisions': [
            'The Pegasus Cavalry',
            'Eagle Riders',
            'Dragon Riders',
            'Aerial Navy',
            'the Evermeet Navy',
            'thousands of magic-users'
        ],
    },
    'languages': ['Elven'],
    'religion': ['The Seldarine'],
    'economy': {
        'exports': ['jewellery', 'exotic and magical items'],
        'imports': ['officially, none'],
    },
    'sources': [
        'Elves of Evermeet - Anne Gray McCready, 1994',
        'Evermeet: Island of Elves - Elaine Cunningham, 1999',
    ],
}

# %%
gundarlun_data = {
    'region': 'Gundarlun',
    'ruler': 'King Olgar Redaxe',
    'capital': {
        'name': 'Gundbarg',
        'population': 12000,
    },
    'settlements': [],
    'population': {
        'total': None,
        'breakdown': {},
        'density': {
            'miles_squared': None,
            'kilometres_squared': None,
        }
    },
    'total_area': {
        'miles_squared': 1829,
        'kilometres_squared': 4737.088,
    },
    'military': {
        'standing': 300,
        'navy': '~30 longships',
    },
    'languages': ['Common', 'Illuskan'],
    'religion': ['Tempus', 'Umberlee'],
    'economy': {
        'exports': [],
        'imports': [],
    },
    'sources': [
        'The Savage Frontier - Jennell Jaquays, 1988',
        'The North - slade, et all, 1996',
    ],
}

ruathym_data = {
    'region': 'Ruathym',
    'ruler': 'King Aumark Lithyl',
    'capital': {
        'name': 'Ruathym',
        'population': 5000,
    },
    'settlements': [
        {'name': 'Hastor', 'population': None},
        {'name': 'Holgerstead', 'population': None},
        {'name': 'Rethgaard', 'population': None},
    ],
    'population': {
        'total': None,
        'breakdown': {},
        'density': {
            'miles_squared': None,
            'kilometres_squared': None,
        }
    },
    'total_area': {
        'miles_squared': 9039,
        'kilometres_squared': 23410.9,
    },
    'military': {
        'tribes': 'Four tribes of warriors and occasional shamans and magic-users',
    },
    'languages': ['Common', 'Ruathen (Illuskan dialect)'],
    'religion': ['Tempus', 'Umberlee'],
    'economy': {
        'exports': [],
        'imports': [],
    },
    'sources': [
        'The Savage Frontier - Jennell Jaquays, 1988',
        'The North - slade, et all, 1996',
    ],
}

trisk_data = {
    'region': 'Trisk (Kingdom of the Purple Rocks)',
    'ruler': 'King Selger',
    'capital': {
        'name': 'Ulf of Thuger',
        'population': None,
    },
    'settlements': [
        {'name': 'Vilkstead', 'population': None},
    ],
    'population': {
        'total': None,
        'breakdown': {},
        'density': {
            'miles_squared': None,
            'kilometres_squared': None,
        }
    },
    'total_area': {
        'miles_squared': 397.5,
        'kilometres_squared': 1029.5,
    },
    'military': {},
    'languages': ['Common', 'Illuskan'],
    'religion': ['Auril', 'Tempus', 'Umberlee'],
    'economy': {
        'exports': ['Fish', 'Vilksmaarg (herbal goat cheese)'],
        'imports': [],
    },
    'sources': [
        'The Savage Frontier - Jennell Jaquays, 1988',
    ],
}

tuern_data = {
    'region': 'Tuern',
    'ruler': [
        'High King Threlked Ironfist',
        'five vassal kings',
    ],
    'capital': {
        'name': 'Uttersea',
        'population': 2000,
    },
    'settlements': [
        {'name': 'Throne Rock', 'population': None},
    ],
    'population': {
        'total': None,
        'breakdown': {},
        'density': {
            'miles_squared': None,
            'kilometres_squared': None,
        }
    },
    'total_area': {
        'miles_squared': 8648,
        'kilometres_squared': 22398.22,
    },
    'military': {},
    'languages': ['Common', 'Illuskan'],
    'religion': ['None, three local red dragons are instead worshipped as gods'],
    'economy': {
        'exports': ['Adamantite ore'],
        'imports': [],
    },
    'sources': [
        'The Savage Frontier - Jennell Jaquays, 1988',
        'The North - slade, et all, 1996',
        'Neverwinter: Tyranny of Dragons - Cryptic Studios, 2014',
        'Storm Kings Thunder - Christopher Perkins, 2016',
    ],
}

# %%
halruaa_data = {
    'region': 'Halruaa',
    'ruler': 'Netyarch Zalathorm Kirkson',
    'capital': {
        'name': 'Halarahh',
        'population': 8000,
    },
    'settlements': [
        {'name': 'Achelar', 'population': None},
        {'name': 'Alathil', 'population': None},
        {'name': 'Alu', 'population': None},
        {'name': 'Aluarim', 'population': None},
        {'name': 'Assundath', 'population': None},
        {'name': 'Bathmé', 'population': None},
        {'name': 'Borah', 'population': None},
        {'name': 'Edouura', 'population': None},
        {'name': 'Elchul', 'population': None},
        {'name': 'Eru', 'population': None},
        {'name': 'Galdel', 'population': None},
        {'name': 'Githim', 'population': None},
        {'name': 'Halabar', 'population': None},
        {'name': 'Halagard', 'population': 7500},
        {'name': 'Halazé', 'population': None},
        {'name': 'Hamphal', 'population': None},
        {'name': 'Khaerbaal', 'population': 7000},
        {'name': 'Kithyym', 'population': None},
        {'name': 'Lath', 'population': None},
        {'name': 'Letharr', 'population': None},
        {'name': 'Lhaddas', 'population': None},
        {'name': 'Lhair', 'population': None},
        {'name': 'Maerass', 'population': None},
        {'name': 'Maeruhal', 'population': None},
        {'name': 'Maerzalar', 'population': None},
        {'name': 'Maezoun', 'population': None},
        {'name': 'Mairb', 'population': None},
        {'name': 'Martass', 'population': None},
        {'name': 'Mithel', 'population': None},
        {'name': 'Mithtar', 'population': None},
        {'name': 'Nishtul', 'population': None},
        {'name': 'Nuulatha', 'population': None},
        {'name': 'Orbedal', 'population': None},
        {'name': 'Rulasuu', 'population': None},
        {'name': 'Rwamphaler', 'population': None},
        {'name': 'Salhantar', 'population': None},
        {'name': 'Ssorsil', 'population': None},
        {'name': 'Sulaziir', 'population': None},
        {'name': 'Talathgard', 'population': 200},
        {'name': 'Thilzoun', 'population': None},
        {'name': 'Thom', 'population': None},
        {'name': 'Yaulazna', 'population': 400},
        {'name': 'Zalazuu', 'population': 5000},
        {'name': 'Zhal', 'population': None},
        {'name': 'Zoundar', 'population': None},
        {'name': 'Zzuntal', 'population': None},
    ],
    'population': {
        'total': 1676160,
        'breakdown': {
            'human': 90,
            'dwarf': 5,
            'halfling': 2,
            'elves': 1,
            'half-elves': 1,
            'misc': 1,
        },
        'density': {
            'miles_squared': 2.65,
            'kilometres_squared': 1.02,
        }
    },
    'total_area': {
        'miles_squared': 631615,
        'kilometres_squared': 1635875.34,
    },
    'military': {
        'defences': 'Magical defences',
        'standing_militia': 'small',
        'fleet': 'small',
        'skyships': True,
    },
    'languages': [
        'Common',
        'Halruaan',
        {'Dambrathan': 'border regions only'},
    ],
    'religion': [
        'Azuth',
        'Mystra',
        'Savras',
        'Shar',
        'Velsharoon',
    ],
    'economy': {
        'exports': [
            'Electrum',
            'gold',
            'Haerlu wine',
        ],
        'imports': [
            'Exotic magic items',
            'jewellery',
            'precious metals',
            'musical instruments',
            'silk',
        ],
    },
    'sources': [
        'The Shining South - Tom Prusa, 1993',
        'Shining South - Todd Gamble, 2004',
    ],
}

# %%
hartsvale_data = {
    'region': 'Hartsvale',
    'ruler': 'Queen Brianna Burdun',
    'capital': {
        'name': 'Hartwick',
        'population': None, # Population data not provided
    },
    'settlements': [
        {'name': 'Cuthbert Castle', 'population': None},
        {'name': 'Stagwick', 'population': None},
        {'name': 'Wendel Manor', 'population': None},
        {'name': 'Windward Town', 'population': None},
        {'name': 'Wynn Castle', 'population': None},
    ],
    'population': {
        'total': None, # Population data not provided
        'breakdown': {
            'human': 96,
            'firbolg': 2,
            'giant': 1,
            'misc': 1,
        }
    },
    'total_area': {
        'miles_squared': 57696,
        'kilometres_squared': 149431.95,
    },
    'military': {
        'strength': None, # Military data not provided
        'composition': None, # Military data not provided
    },
    'languages': [
        'Common',
        {'Bothii': 'Illuskan dialect'},
    ],
    'religion': [
        'Iallanis',
    ],
    'economy': {
        'exports': None, # Export data not provided
        'imports': None, # Import data not provided
    },
    'sources': [
        'The Twilight Giants trilogy - Troy Denning, 1994-95',
        'Giantcraft - Ray Winninger, 1995',
        'Sword Coast Adventurer’s Guide - Steven Kenson et al, 2015',
    ],
}

# %%
impiltur_data = {
    'region': 'Impiltur',
    'ruler': {
        'monarch': 'King Imbrar II',
        'heir': 'King Imbrar II',
        'regent': 'Queen Regent Sambryl',
        'council': 'The Lords of Imphras II',
    },
    'capital': {
        'name': 'Lyrabar',
        'population': 52305,
    },
    'settlements': [
        {'name': "Arn’s Cove", 'population': None},
        {'name': "Bay Town", 'population': 1750},
        {'name': "Borgar’s Mill", 'population': None},
        {'name': "Cairnpur", 'population': None},
        {'name': "Dilpur", 'population': 15000},
        {'name': "Filur", 'population': None},
        {'name': "Guidodale", 'population': None},
        {'name': "Hlammach", 'population': 36386},
        {'name': "Ilmwatch", 'population': 560},
        {'name': "Kielbast", 'population': None},
        {'name': "Laviguer", 'population': None},
        {'name': "Lenchford", 'population': None},
        {'name': "Maracrath", 'population': None},
        {'name': "Mulltown", 'population': 250},
        {'name': "New Moranay", 'population': 1356},
        {'name': "New Sarshel", 'population': 1500},
        {'name': "Outentown", 'population': None},
        {'name': "Pick ‘n’ Axe", 'population': None},
        {'name': "Red Bluffs", 'population': None},
        {'name': "Relgar’s Ford", 'population': None},
        {'name': "Sarshel", 'population': 6000},
        {'name': "Songhal", 'population': None},
        {'name': "Thelnam", 'population': None},
        {'name': "Three Horns", 'population': None},
        {'name': "Timbertown", 'population': None},
        {'name': "Vordric Dun", 'population': None},
    ],
    'population': {
        'total': 1205280,
        'breakdown': {
            'human': 90,
            'dwarf': 5,
            'halfling': 4,
            'misc': 1,
        },
    },
    'total_area': {
        'miles_squared': 116266,
        'kilometres_squared': 301127.6,
    },
    'population_density': {
        'people_per_mile_squared': 10.37,
        'people_per_km_squared': 4.00,
    },
    'military': [
        'The Warswords',
        'The Most Holy Order of the Sacred Shrike',
        'The Triadic Knights',
        'The Swordpoints',
    ],
    'languages': ['Common', 'Damaran'],
    'religion': ['Ilmater', 'Selûne', 'Torm', 'Tymora', 'Tyr', 'Valkur', 'Waukeen'],
    'economy': {
        'exports': [
            'Gems',
            'Bloodstone',
            'Gold',
            'Iron',
            'Silver',
            'Trade goods from Damara and Earthfast',
        ],
        'imports': [
            'Exotic goods',
            'Fruit',
            'Shipbuilders',
            'Tea',
            'Vegetables',
            'Wood products',
        ],
    },
    'sources': [
        'The Bloodstone Lands - Bob Salvatore, 1989',
        'Impiltur: The Forgotten Kingdom - George Krashos, Dragon #346, August 2006',
        'The Grand History of the Realms - Brian R. James, Ed Greenwood, George Krashos, Eric L. Boyd, Thomas Costa, 2007',
    ],
}

# %%
lantan_data = {
    'region': 'Lantan',
    'ruler': {
        'name': 'Ayrar Thagr',
        'position': 'Chairperson of the Ayrorch',
    },
    'capital': {
        'name': 'Sambar',
        'population': None,
    },
    'settlements': [
        {'name': 'Anchoril', 'population': None},
        {'name': 'Baelrah', 'population': None},
        {'name': 'Darluj', 'population': None},
        {'name': 'Dtakkar', 'population': None},
        {'name': 'Illul', 'population': None},
        {'name': 'Lethtar', 'population': None},
        {'name': 'Sundrah', 'population': None},
        {'name': 'Sujjar', 'population': None},
        {'name': 'Tsan', 'population': None},
    ],
    'population': {
        'total': None,
        'breakdown': {
            'human': 'Unknown',
            'gnomes': 'Unknown',
            'sentient wombats': 'Small population',
            'platypuses': 'Small population',
            'other': '1 vengeance-obsessed cat (Silky)',
        },
    },
    'total_area': {
        'miles_squared': 35538,
        'kilometres_squared': 92042.997,
    },
    'military': [
        'A powerful, technologically-advanced navy',
        'A strong militia',
        'Illusionists',
    ],
    'languages': [
        'Common',
        'Gnomish',
        'Lantanese',
        'Alzhedo',
        'Chondathan',
        'Dwarvish',
        'Ignan',
        'Illuskan',
        'Shaaran',
    ],
    'religion': ['Gond', 'Azuth', 'Gnomish pantheon'],
    'economy': {
        'exports': ['Technology (mostly things that explode, or encourage explosions in others)'],
        'imports': ['Copper', 'Gemstones', 'Tin', 'Wood'],
    },
    'sources': [
        'Forgotten Realms Campaign Setting - Jeff Grubb, Ed Greenwood, Karen S. Martin, 1987',
        'The Ring of Winter - James Lowder, 1992',
        'Perilous Gateways: Portals of Lantan - Jeff Quick, 2004 web enhancement',
    ],
}

# %%
lapaliiya_data = {
    'region': 'Lapaliiya',
    'ruler': {
        'name': 'Shaliim Wyrmslayer',
        'title': 'Overking of Sheirtalar'
    },
    'capital': {
        'name': 'Sheirtalar',
        'population': 52135,
    },
    'settlements': [
        {'name': 'Abreon', 'population': 4680},
        {'name': 'Dungar', 'population': 931},
        {'name': 'Ilyaport', 'population': 1923},
        {'name': 'Ithmong', 'population': 46729},
        {'name': 'Lapalgard', 'population': 3701},
        {'name': 'Lhazantal', 'population': 925},
        {'name': 'Lushpool', 'population': 17265},
        {'name': 'Malaxer', 'population': 4103},
        {'name': 'Mierskar', 'population': 1617},
        {'name': 'Ormpur', 'population': 24612},
        {'name': 'Sammaresh', 'population': 21912},
        {'name': 'Sheirlantar', 'population': 7306},
        {'name': 'Uzurr', 'population': 10305},
        {'name': 'Zashuma', 'population': 1399},
    ],
    'population': {
        'total': 1217642,
        'breakdown': {
            'human': 94,
            'yuan-ti': 2,
            'gnome': 2,
            'dwarf': 1,
            'miscellaneous': 1,
        },
    },
    'population_density': {
        'miles_squared': 8.13,
        'kilometres_squared': 3.14,
    },
    'area': {
        'miles_squared': 149820,
        'kilometres_squared': 388032.019,
    },
    'military': ['Local militias', 'Mercenary companies'],
    'languages': ['Common', 'Shaaran', 'Tashalan', 'Alzhedo', 'Halruaan'],
    'religion': [
        'Bhaelros (Talos)', 'Chauntea', 'Deneir', 'Eldath', 'Garl Glittergold',
        'Gond', 'Ilmater', 'Kelemvor', 'Lliira', 'Selûne', 'Silvanus', 'Tempus',
        'Tiamat', 'Umberlee', 'Waukeen',
    ],
    'economy': {
        'exports': ['Olives', 'Pearls', 'Roe', 'Seafood', 'Spices', 'Wine', 'Wood'],
        'imports': ['Armour', 'Beef', 'Gems', 'Fruit', 'Iron', 'Jewellery', 'Pottery', 'Weapons'],
    },
    'sources': [
        'Serpent Kingdoms - Ed Greenwood, Eric L. Boyd, Darrin Drader, 2004',
    ],
}

tharsult_data = {
    'region': 'Tharsult',
    'ruler': {
        'type': 'Merchant oligarchy',
    },
    'capital': {
        'name': 'Urbeth',
        'population': None,
    },
    'settlements': [
        {'name': 'Aunthurr', 'population': None},
        {'name': 'Chastel', 'population': None},
        {'name': 'Funearil', 'population': None},
        {'name': 'Nlintar', 'population': None},
        {'name': 'Tunumbar', 'population': None},
        {'name': 'Zoana', 'population': None},
    ],
    'population': {
        'total': None,
    },
    'area': {
        'miles_squared': 7069,
        'kilometres_squared': 18308.63,
    },
    'military': None,
    'languages': ['Common', 'Shaaran', 'Tashalan', 'Alzhedo', 'Halruaan'],
    'religion': ['Waukeen', 'Various'],
    'economy': {
        'exports': ['Food', 'Mercantile services'],
        'imports': ['Everything'],
    },
    'sources': [
        'Perilous Gateways: Portals in Ruins - Robert Wiese, 2002',
        'Ed Greenwood’s comments - Link (URL not provided)',
        'Realmslore: Tharsult - Ed Greenwood, 2022, via Patreon',
    ],
}

# %%
luiren_data = {
    'region': 'Luiren',
    'ruler': {
        'name': 'Faran Ferromar',
        'title': 'Devout Voice'
    },
    'capital': {
        'name': 'Beluir',
        'population': 27210,
    },
    'settlements': [
        {'name': 'Ammathluir', 'population': 10000},
        {'name': 'Chethel', 'population': 15512},
        {'name': 'Crimel', 'population': 1000},
        {'name': 'Djannath', 'population': None},
        {'name': 'Fasruil', 'population': 3000},
        {'name': 'Krenadir', 'population': None},
        {'name': 'Lluirvale', 'population': None},
        {'name': 'Otennath', 'population': None},
        {'name': 'Shoun', 'population': None},
    ],
    'population': {
        'total': 838080,
        'breakdown': {
            'halfling': 92,
            'human': 4,
            'elf': 2,
            'half-elf': 1,
            'miscellaneous': 1,
        },
    },
    'population_density': {
        'miles_squared': 4.77,  # 838080 / 175783
        'kilometres_squared': 1.84,  # 838080 / 455275.88
    },
    'area': {
        'miles_squared': 175783,
        'kilometres_squared': 455275.88,
    },
    'military': ['Town militias', 'A small navy', 'The marchwardens (frontier guards)'],
    'languages': ['Common', 'Dambrathan', 'Durpari', 'Halfling (Luiric/Lurienal)'],
    'religion': ['Brandobaris', 'Tymora', 'Yondalla', 'The halfling pantheon'],
    'economy': {
        'exports': ['Ale', 'Beer', 'Grain', 'Fruit', 'Produce'],
        'imports': ['Metalwork items', 'Livestock'],
    },
    'sources': [
        'The Shining South - Tom Prusa, 1993',
        'Demihuman Deities - Eric L. Boyd, 1998',
        'Shining South - Todd Gamble, 2004',
    ],
}

# %%
silver_marches_data = {
    "region": "The Silver Marches",
    "ruler": {
        "name": "Alustriel Silverhand",
        "title": "High Lady"
    },
    "capital": {
        "name": "Silverymoon",
        "population": 37073,
    },
    "settlements": [
        {"name": "Auvandell", "population": 524},
        {"name": "Blumberg", "population": None},
        {"name": "Citadel Adbar", "population": 19962},
        {"name": "Citadel Felbarr", "population": 6987},
        {"name": "Deadsnows", "population": 830},
        {"name": "Everlund", "population": 21388},
        {"name": "Hilltop", "population": 100},
        {"name": "Jalanthar", "population": 226},
        {"name": "Khelb", "population": None},
        {"name": "Lhuvenhead", "population": None},
        {"name": "Mithral Hall", "population": 4991},
        {"name": "Newfort", "population": 138},
        {"name": "Quaervaar", "population": 952},
        {"name": "Rauvincross", "population": None},
        {"name": "Rivermoot", "population": None},
        {"name": "Sundabar", "population": 14259},
        {"name": "Winter's Edge", "population": None}
    ],
    "population": {
        "total": 1090800,
        "breakdown": {
            "human": 40,
            "dwarf": 20,
            "elf": 20,
            "half-elf": 10,
            "halfling": 5,
            "gnome": 2,
            "half-orc": 2,
            "miscellaneous": 1,
        },
    },
    "population_density": {
        "miles_squared": 6.77,
        "kilometres_squared": 2.61
    },
    "area": {
        "miles_squared": 161206,
        "kilometres_squared": 417521.623,
    },
    "military": [
        "The Argent Legion",
        "Local militias"
    ],
    "languages": [
        "Common",
        "Chondathan",
        "Illuskan"
    ],
    "religion": [
        "Corellon Larethian",
        "Helm",
        "Lathander",
        "Lurue",
        "Mielikki",
        "Moradin",
        "Mystra",
        "Oghma",
        "Selûne",
        "Sune",
        "Tymora"
    ],
    "economy": {
        "exports": [
            "Elven craftwork",
            "Dwarven craftwork",
            "Furs",
            "Precious metals"
        ],
        "imports": [
            "Armour",
            "Books",
            "Manufactured goods",
            "Pottery",
            "Spices",
            "Wine"
        ],
    },
    "sources": [
        "The North (slade, Ed Greenwood, Jeff Grubb, Julia Martin, Steven Schend, Jennell Jaquays, Steve Perrin, 1996)",
        "Silver Marches (Ed Greenwood, Jason Carl, 2002)"
    ],
}

# %%
mintarn_data = {
    "region": "Mintarn",
    "ruler": {
        "name": "Tarnheel Embuirhan",
        "title": "Dictator"
    },
    "capital": "Mintarn",
    "population": {
        "total": None,
        "breakdown": {
            "human": "most",
            "dwarf": "small number",
            "merfolk": "small number",
        }
    },
    "area": {
        "miles_squared": 617,
        "kilometres_squared": 1598.02,
    },
    "languages": [
        "Common",
        "Illuskan"
    ],
    "religion": [
        "Umberlee"
    ],
    "economy": {
        "exports": [
            "Ships",
            "Mercenaries",
            "Food"
        ],
        "imports": [
            "Moonshae wood",
            "Mabadann oysters"
        ],
    },
    "sources": [
        "Treasures of the Savage Frontier (video game, 1992)",
        "Passage to Dawn (R.A. Salvatore, 1996)"
    ],
}

# %%
orlumbor_data = {
    "region": "Orlumbor",
    "ruler": {
        "name": "Tulgar Wrightsson",
        "title": None
    },
    "capital": {
        "name": "Orlumbor",
        "population": 1600,
    },
    "settlements": [
        {"name": "Farr Windward", "population": None},
    ],
    "population": {
        "total": None,
        "breakdown": {
            "human": "most",
        }
    },
    "area": {
        "miles_squared": 310,
        "kilometres_squared": 802.89,
    },
    "languages": [
        "Common",
        "Illuskan"
    ],
    "religion": [
        "Talos"
    ],
    "economy": {
        "exports": [
            "Ships"
        ],
        "imports": [
            "Wood"
        ],
    },
    "sources": [
        "Treasures of the Savage Frontier (video game, 1992)"
    ],
}

# %%
moonshae_data = {
    "region": "Moonshae",
    "ruler": {"name": "High Queen Alicia Kendrick", "title": None},
    "capital": "Caer Callidyrr",
    "settlements": [
        {"name": "Aithelar", "population": 10000},
        {"name": "Blackstone", "population": None},
        {"name": "Blythe", "population": None},
        {"name": "Borth", "population": None},
        {"name": "Bounty", "population": None},
        {"name": "Brannoch", "population": None},
        {"name": "Bray", "population": None},
        {"name": "Cambro", "population": None},
        {"name": "Caer Corwell", "population": None},
        {"name": "Caer Moray", "population": None},
        {"name": "Caer Westphal", "population": None},
        {"name": "Caervu", "population": None},
        {"name": "Cobh", "population": None},
        {"name": "Codfin", "population": None},
        {"name": "Codscove", "population": None},
        {"name": "Doncastle", "population": None},
        {"name": "Dorset", "population": None},
        {"name": "Dultann", "population": None},
        {"name": "Dynnatt", "population": None},
        {"name": "Dynnegall", "population": None},
        {"name": "Elyssyrr", "population": None},
        {"name": "Farview", "population": None},
        {"name": "Fenton", "population": None},
        {"name": "Grady", "population": None},
        {"name": "Graystone", "population": None},
        {"name": "Grimstad", "population": None},
        {"name": "Harloch", "population": None},
        {"name": "Hickorydale", "population": None},
        {"name": "Horsa", "population": None},
        {"name": "Horst", "population": None},
        {"name": "Highhome", "population": None},
        {"name": "Highrock", "population": None},
        {"name": "Holyhead", "population": None},
        {"name": "Horstall", "population": None},
        {"name": "Hyoclaatl", "population": None},
        {"name": "Kingsbay", "population": None},
        {"name": "Koart", "population": None},
        {"name": "Kork", "population": None},
        {"name": "Kythyss", "population": None},
        {"name": "Lehigh", "population": None},
        {"name": "Llandrain", "population": None},
        {"name": "Llewellyn", "population": None},
        {"name": "Lowhill", "population": None},
        {"name": "MacSheehan", "population": None},
        {"name": "Manger", "population": None},
        {"name": "Myrrdale", "population": None},
        {"name": "Ogden", "population": None},
        {"name": "O’Malley", "population": None},
        {"name": "Pembroke", "population": None},
        {"name": "Pengram", "population": None},
        {"name": "Pontswain", "population": None},
        {"name": "Regents Field", "population": None},
        {"name": "Storaad", "population": None},
        {"name": "Tetauctaa", "population": None},
        {"name": "Thorndyke", "population": None},
        {"name": "White Rock", "population": None},
        {"name": "Wyngate", "population": None},
    ],
    "population": {"total": 680400, "breakdown": {"human": "89%", "halfling": "4%", "elf": "3%", "dwarf": "2%", "half-elf": "1%", "misc": "1%"}},
    "population_density": {"per_mile_squared": 9.17, "per_km_squared": 3.54},
    "area": {"miles_squared": 74169, "kilometres_squared": 192097},
    "military": "Various local militias",
    "languages": ["Aquan", "Chondathan", "Common", "Dwarven", "Elven", "Giant", "Illuskan", "Sylvan"],
    "religion": ["The Earthmother", "Chauntea", "Tempus"],
    "economy": {"exports": ["Armour", "rose-gold", "timber", "weapons"], "imports": ["Coal", "horses", "minor magical items", "ore", "parchment", "silk"]},
    "sources": ["Moonshae (Douglas Niles, 1987)", "Halls of the High King (Ed Greenwood, 1990)", "Backdrop: The Moonshae Isles (Shawn Merwin, Dungeon #196, 2011)"],
}

norland_data = {
    "region": "Norland",
    "ruler": {"name": None, "title": None},
    "capital": "Rogarsheim",
    "settlements": [
        {"name": "Arfinnsheim", "population": None},
        {"name": "Arndtbergom", "population": None},
        {"name": "Follebu", "population": None},
        {"name": "Iron Keep", "population": None},
        {"name": "Gudbrandstad", "population": None},
        {"name": "Ramshorn", "population": None},
        {"name": "Skien", "population": None},
        {"name": "Sommersdal", "population": None},
        {"name": "Sordal", "population": None},
        {"name": "Trondheim", "population": None},
        # Continue adding settlements and populations here
    ],
    "population": None,
    "area": {"miles_squared": 21250, "kilometres_squared": 55037},
    "military": "Local militias, warbands, raiding parties",
    "languages": ["Common", "Rashemi"],
    "religion": ["Auril", "Talos", "Tempus", "Umberlee", "Valkur"],
}
norheim_data = {
    "region": "Norheim",
    "ruler": {"name": "King Hammerstaad", "title": None},
    "capital": "Hammerstaad",
    "settlements": [
        {"name": "Dalheim", "population": None},
        {"name": "Daryn’s Rest", "population": None},
        {"name": "Graystaad", "population": None},
        {"name": "Rottesheim", "population": None},
        {"name": "Seawolf", "population": None},
        {"name": "Threlloch", "population": None},
        # Continue adding settlements and populations here
    ],
    "population": None,
    "area": {"miles_squared": 2750, "kilometres_squared": 7122},
    "military": "Local militias, warbands, raiding parties",
    "languages": ["Common", "Rashemi"],
    "religion": ["Auril", "Talos", "Tempus", "Umberlee", "Valkur"],
    "economy": {"exports": ["Minerals", "metals", "slaves", "weapons"], "imports": ["Alcohol", "food", "gold"]},
}
gnarhelm_data = {
    "region": "Gnarhelm",
    "ruler": {"name": "King Brandon Olafsson", "title": None},
    "capital": "Gnarhelm",
    "settlements": [
        {"name": "Olafstaad", "population": None},
        {"name": "Otta", "population": None},
        {"name": "Sunderstaad", "population": None},
        {"name": "Warlsbry", "population": None},
    ],
    "population": None,
    "area": {"miles_squared": 15876, "kilometres_squared": 41119},
    "military": "Local militias, warbands, raiding parties",
    "languages": ["Common", "Rashemi"],
    "religion": ["Auril", "Talos", "Tempus", "Umberlee", "Valkur"],
    "economy": {"exports": ["Minerals", "metals", "slaves", "weapons"], "imports": ["Alcohol", "food", "gold"]},
}
synnoria_data = {
    "region": "Synnoria",
    "ruler": {
        "name": None,
        "title": None
    },
    "capital": "Chrysalis",
    "population": {
        "total": None,
        "breakdown": {
            "elves": ">99%"
        }
    },
    "area": {
        "miles_squared": 90,
        "kilometres_squared": 233,
    },
    "military": "The Sisters of Synnoria (cavalry company)",
    "languages": ["Common", "Rashemi"],
    "religion": ["Earthmother"],
    "economy": {
        "exports": [],
        "imports": [],
    },
    "sources": [
        "Moonshae (Douglas Niles, 1987)",
        "Halls of the High King (Ed Greenwood, 1990)",
        "Backdrop: The Moonshae Isles (Shawn Merwin, Dungeon #196, 2011)"
    ],
}

# %%
mulhorand_data = {
    "region": "Mulhorand",
    "ruler": {"name": "Pharaoh Horustep III", "title": None},
    "capital": {"name": "Skuld", "population": 204538},
    "settlements": [
        {"name": "Aina", "population": None},
        {"name": "Delgora", "population": None},
        {"name": "Gheldaneth", "population": 172430},
        {"name": "Jhalhoran", "population": None},
        {"name": "Klondor", "population": None},
        {"name": "Maerlar", "population": None},
        {"name": "Mishtan", "population": 6459},
        {"name": "Neldorild", "population": 40000},
        {"name": "Rauthil", "population": None},
        {"name": "Sampranasz", "population": 3000},
        {"name": "Sultim", "population": None},
        {"name": "Surbroar", "population": None},
        {"name": "Ulzel", "population": None},
        # Continue adding settlements and populations here
    ],
    "population": {
        "total": 5339520,
        "breakdown": {"human": "99%", "miscellaneous": "1%"},
        "density": {"miles_squared": 17.64, "kilometres_squared": 6.81},
    },
    "area": {"miles_squared": 302688, "kilometres_squared": 783958.321},
    "military": "One of the largest armies and navies in Faerûn, plus allied mercenary forces such as the Gold Swords",
    "languages": ["Common", "Muhjuri", "Mulhorandi"],
    "religion": [
        "The Mulhorandi pantheon",
        "Gond",
        "Mask",
        "Mystra",
        "Red Knight"
    ],
    "economy": {
        "exports": ["Ale", "beer", "blank spellbooks", "gold", "granite", "paper", "precious stones"],
        "imports": ["Fine timber", "incense", "iron", "perfume", "slaves", "spices"],
    },
    "sources": [
        "The Old Empires (Scott Bennie, 1990)",
        "The God-Kings of Mulhorand (Ed Greenwood, George Krashos, 2020, on Twitter)"
    ],
}

# %%
murghom_data = {
    "region": "Murghôm",
    "ruler": {"name": "King Tharmakkas IV", "title": "Bey of Murghôm"},
    "capital": {"name": "Murghyr", "population": None},
    "settlements": [
        {"name": "Alzayat", "population": None},
        {"name": "Athab", "population": None},
        {"name": "Delbyl", "population": None},
        {"name": "Diyala", "population": None},
        {"name": "Fars", "population": None},
        {"name": "Ghaws", "population": None},
        {"name": "Graumot", "population": None},
        {"name": "Hashimyl", "population": None},
        {"name": "Hatra", "population": None},
        {"name": "Isa", "population": None},
        {"name": "Isfasan", "population": None},
        {"name": "Jurash", "population": None},
        {"name": "Khuld", "population": None},
        {"name": "Kilastann", "population": None},
        {"name": "Madan", "population": None},
        {"name": "Mulharahold", "population": None},
        {"name": "Phannaskul", "population": None},
        {"name": "Port Ghaast", "population": None},
        {"name": "Rume", "population": None},
        {"name": "Sinilyr", "population": None},
        {"name": "Somraggah", "population": None},
        {"name": "Sughra", "population": None},
        {"name": "Taj", "population": None},
        {"name": "Thalathat", "population": None},
        {"name": "Thandyl", "population": None},
        {"name": "Tuulish", "population": None},
        {"name": "Umarah", "population": None},
        {"name": "Ustann", "population": None},
        {"name": "Wakirnayskul", "population": None},
        {"name": "Zindalankh", "population": None},
        # Continue adding settlements and populations here
    ],
    "population": {
        "total": None,
        "breakdown": None,
        "density": {"miles_squared": None, "kilometres_squared": None},
    },
    "area": {"miles_squared": 226689, "kilometres_squared": 587121.815},
    "military": "Strong militias and allied mercenary companies",
    "languages": ["Common", "Muhjuri", "Mulhorandi"],
    "religion": ["The Mulhorandi pantheon", "The Muhjari"],
    "economy": {
        "exports": ["Copper", "jasper", "chalcedony", "date palms", "giant sturgeon", "lumber"],
        "imports": [],
    },
    "sources": [
        "Old Empires (Scott Bennie, 1990)",
        "Horde Campaign (Curtis M. Scott, 1990)",
        "The Horde (David Cook, 1990)"
    ],
}

# %%
semphar_data = {
    "region": "Semphar",
    "ruler": {"name": "Caliph Abu Bakr", "title": None},
    "capital": {"name": "Dhaztanar", "population": None},
    "settlements": [
        {"name": "Anbar", "population": None},
        {"name": "Baduraya", "population": None},
        {"name": "Banawari", "population": None},
        {"name": "Banu", "population": None},
        {"name": "Darabjind", "population": None},
        {"name": "Dar al-Kalif", "population": None},
        {"name": "Darabjind", "population": None},
        {"name": "Darrabhal", "population": None},
        {"name": "Duirtanal", "population": None},
        {"name": "Estanil", "population": None},
        {"name": "Fustat", "population": None},
        {"name": "Harb", "population": None},
        {"name": "Iliphanar", "population": None},
        {"name": "Isabadah", "population": None},
        {"name": "Jurjan", "population": None},
        {"name": "Khalis", "population": None},
        {"name": "Maristan", "population": None},
        {"name": "Merv", "population": None},
        {"name": "Naysabur", "population": None},
        {"name": "Nihawand", "population": None},
        {"name": "Phelzel", "population": None},
        {"name": "Quas al-Hasani", "population": None},
        {"name": "Quas al’Tarik", "population": None},
        {"name": "Qumis", "population": None},
        {"name": "Saaid", "population": None},
        {"name": "Semkhrun", "population": None},
        {"name": "Semlithol", "population": None},
        {"name": "Shahar", "population": None},
        {"name": "Simman", "population": None},
        {"name": "Siniyat", "population": None},
        {"name": "Takrit", "population": None},
        {"name": "Taquasma", "population": None},
        {"name": "Uman", "population": None},
        {"name": "Wadieska’b", "population": None},
        {"name": "Zabad", "population": None},
        # Continue adding settlements and populations here
    ],
    "population": {
        "total": None,
        "breakdown": None,
        "density": {"miles_squared": None, "kilometres_squared": None},
    },
    "area": {"miles_squared": 326713, "kilometres_squared": 846182.785},
    "military": "Strong militias and a very strong navy on Brightstar Lake",
    "languages": ["Common", "Muhjuri", "Mulhorandi"],
    "religion": ["The Muhjari", "The Mulhorandi pantheon"],
    "economy": {
        "exports": ["Horses", "Duir leather", "leather goods", "lumber", "ships"],
        "imports": [],
    },
    "sources": [
        "Old Empires (Scott Bennie, 1990)",
        "Horde Campaign (Curtis M. Scott, 1990)",
        "The Horde (David Cook, 1990)"
    ],
}

# %%
narfell_data = {
    "region": "Narfell",
    "ruler": {"name": "Thalaman Harthgroth", "title": "Ruler of the Harthgroth tribe and Head of the Nar Tribal Council"},
    "capital": {"name": "Bildoobaris", "population": 30000},
    "settlements": [
        {"name": "Antlerbones", "population": None},
        {"name": "Hoarbridge", "population": None},
        {"name": "Jiyyd", "population": None},
        {"name": "Nar-Sek Qu’encesta", "population": None},
        {"name": "Nar-Sek Qu’istrade", "population": None},
        {"name": "Nar-Sek Qu’tel", "population": None},
        {"name": "N’Jast", "population": None},
        {"name": "Peltarch", "population": None},
        {"name": "Selmast", "population": None},
        {"name": "Snowcap", "population": None},
    ],
    "population": {
        "total": 36720,
        "breakdown": {"human": 99, "miscellaneous": 1},
        "density": {"miles_squared": 0.16, "kilometres_squared": 0.06},
    },
    "area": {"miles_squared": 223903, "kilometres_squared": 579906.108},
    "military": "Individual tribal warriors",
    "languages": ["Common", "Damaran", "Rashemi"],
    "religion": ["Lathander", "Tempus", "Waukeen"],
    "economy": {
        "exports": ["Horses"],
        "imports": ["Clothing", "jewellery"],
    },
    "sources": [
        "The Bloodstone Lands (Bob Salvatore, 1989)",
        "The Horde (David Cook, 1990)",
        "Unapproachable East (Richard Baker, Matt Forbeck, Sean K. Reynolds, 2003)",
        "Lost Empires of Faerûn (Richard Baker, Ed Bonny, Travis Stout, 2005)",
    ],
}

# %%
nimbral_data = {
    "region": "Nimbral",
    "ruler": "The Nimbral Lords",
    "capital": {"name": "Selpir", "population": None},
    "settlements": [
        {"name": "Arevar", "population": None},
        {"name": "Bromtor", "population": None},
        {"name": "Curstallyon", "population": None},
        {"name": "Esdul", "population": None},
        {"name": "Nimith", "population": None},
        {"name": "Nimsur", "population": None},
        {"name": "Ormen", "population": None},
        {"name": "Rauthaven", "population": None},
        {"name": "Sombor", "population": None},
        {"name": "Suthaven", "population": None},
        {"name": "Tethmor", "population": None},
        {"name": "Vindal", "population": None},
    ],
    "population": {"total": None, "breakdown": {"human": 90, "half-elf": 10}},
    "area": {"miles_squared": 42424, "kilometres_squared": 109877.66},
    "military": "The Knights of the Flying Hunt (airborne cavalry)",
    "languages": ["Common", "Halruaan"],
    "religion": ["Deneir", "Lurue"],
    "economy": {"exports": [], "imports": []},
    "sources": ["The Realm of Nimbral (Ed Greenwood, Wizards of the Coast website, archived here, 2004)"],
}

# %%
rashemen_data = {
    "region": "Rashemen",
    "ruler": "Huhrong (Iron Lord) Thydrim Yvarrg",
    "capital": {"name": "Immilmar", "population": 21210},
    "settlements": [
        {"name": "Citadel Rashemar", "population": 760},
        {"name": "Mulptan", "population": 6900},
        {"name": "Mulsantir", "population": 4848},
        {"name": "Nathoud", "population": None},
        {"name": "Shevel", "population": None},
        {"name": "Taporan", "population": 1000},
        {"name": "Thasunta", "population": 2150},
        {"name": "Tinnir", "population": 540},
        {"name": "Urling", "population": 400},
    ],
    "population": {
        "total": 654480,
        "breakdown": {"human": 99, "misc.": 1},
        "density": {"per_mile_squared": 1.73, "per_kilometre_squared": 0.67},
    },
    "area": {"miles_squared": 377141, "kilometres_squared": 976790.706},
    "military": "Strong military culture, berserker lodges, standing militias, and magical support from the Wychlaran",
    "languages": ["Common", "Rashemi"],
    "religion": ["Bhalla (Chauntea)", "Khelliara (Mielikki)", "the Hidden One (Mystra)"],
    "economy": {"exports": ["Carvings", "cheese", "firewine", "furs", "wool"], "imports": ["Cloth", "food", "wood products"]},
    "sources": ["Spellbound (Anthony Pryor, 1995)", "Unapproachable East (Richard Baker, Matt Forbeck, Sean K. Reynolds, 2003)"],
}

# %%
samarach_data = {
    "region": "Samarach",
    "ruler": "High Phantasmage (Archmage) Meleghost Zoaster",
    "capital": {"name": "Samargol", "population": 105731},
    "settlements": [
        {"name": "Ahoyahoy", "population": None},
        {"name": "Dangwaru", "population": None},
        {"name": "Nimbre", "population": None},
        {"name": "Rassatan", "population": 10936},
        {"name": "Serl", "population": None},
        {"name": "Taruin", "population": 23899},
        {"name": "Torich", "population": None},
    ],
    "population": {
        "total": 434510,
        "breakdown": {"human": 98, "yuan-ti": 1, "misc.": 1},
        "density": {"per_mile_squared": 4.44, "per_kilometre_squared": 1.71},
    },
    "area": {"miles_squared": 97937, "kilometres_squared": 253655.67},
    "military": "Local militias, can call upon the Knights of the Flying Hunt of Nimbral for aid",
    "languages": ["Common", "Chultan", "Tashalan"],
    "religion": ["Leira", "Set", "Squamata the Black (Sseth)"],
    "economy": {"exports": ["Pearls", "salt", "spices"], "imports": ["Weapons"]},
    "sources": ["Serpent Kingdoms (Ed Greenwood, Eric L. Boyd, Darrin Drader, 2004)", "Neverwinter Nights 2: Storm of Zehir (video game, Obsidian Entertainment / Atari, 2008)"],
}

# %%
thindol_data = {
    "region": "Thindol",
    "ruler": "The Council of Cities",
    "capital": {"name": "Thindar", "population": 98662},
    "settlements": [
        {"name": "Aztul", "population": 4631},
        {"name": "Deltar", "population": 2863},
        {"name": "Delselar", "population": 76412},
        {"name": "Gurdeth", "population": 17991},
        {"name": "Lundeth", "population": 23791},
        {"name": "Narubel", "population": 11301},
        {"name": "Psamma", "population": 1936},
        {"name": "Samargard", "population": None},
        {"name": "Tchinggult", "population": 3413},
    ],
    "population": {
        "total": 1263413,
        "breakdown": {"human": 86, "gold dwarf": 7, "kuo-toa": 3, "lizardfolk": 2, "yuan-ti": 1, "misc.": 1},
        "density": {"per_mile_squared": 10.26, "per_kilometre_squared": 3.96},
    },
    "area": {"miles_squared": 123071, "kilometres_squared": 318752.427},
    "military": "Local militias",
    "languages": ["Common", "Chultan", "Tashalan"],
    "religion": ["Lathander", "Lliira", "Malar", "Savras", "Set", "Tymora"],
    "economy": {"exports": ["Gold", "iron", "seafood", "tropical fruits and vegetables", "weapons"], "imports": ["Grains", "wine", "wood"]},
    "sources": ["Serpent Kingdoms (Ed Greenwood, Eric L. Boyd, Darrin Drader, 2004)"],
}

# %%
tashalar_data = {
    "region": "Tashalar",
    "ruler": "Merchant oligarchy council",
    "capital": {"name": "Tashluta", "population": 51522},
    "settlements": [],
    "population": {
        "total": 889920,
        "breakdown": {"human": 94, "lizardfolk": 4, "yuan-ti": 1, "misc.": 1},
        "density": {"per_mile_squared": 46.38, "per_kilometre_squared": 17.91},
    },
    "area": {"miles_squared": 19182, "kilometres_squared": 49681.152},
    "military": "Local militias, can call upon mercenary aid from Lapaliiya",
    "languages": ["Common", "Chultan", "Tashalan"],
    "religion": ["Chauntea", "Bhaelros (Talos)", "Malar", "Savras", "Sseth (Set, the World Serpent)", "Talona Waukeen"],
    "economy": {
        "exports": [
            "Calantra carvings",
            "cheese",
            "coffee",
            "crossbows",
            "dyed fabric",
            "glass",
            "olive oil",
            "olives",
            "perfume",
            "seafood",
            "ships",
            "spices",
            "wine",
            "wood",
        ],
        "imports": ["Beef", "calantra", "fruit", "kaeth", "silver", "slaves"],
    },
    "sources": ["Serpent Kingdoms (Ed Greenwood, Eric L. Boyd, Darrin Drader, 2004)"],
}

# %%
sembia_data = {
    "region": "Sembia",
    "ruler": "Overmaster Elduth Yarmmaster",
    "capital": {"name": "Ordulin", "population": 36330},
    "settlements": [
        {"name": "Daerlun", "population": 52477},
        {"name": "Huddagh", "population": None},
        {"name": "Kulta", "population": None},
        {"name": "Mulhessen", "population": None},
        {"name": "Saerb", "population": None},
        {"name": "Saerloon", "population": 54496},
        {"name": "Selgaunt", "population": 56514},
        {"name": "Surd", "population": None},
        {"name": "Tulbegh", "population": None},
        {"name": "Uarhold", "population": None},
        {"name": "Urmlaspyr", "population": 26239},
        {"name": "Yhaunn", "population": 20184},
        {"name": "Yuthgalaunt", "population": None},
    ],
    "population": {
        "total": 2462400,
        "breakdown": {"human": 96, "halfling": 3, "misc.": 1},
        "density": {"per_mile_squared": 27.78, "per_kilometre_squared": 10.73},
    },
    "area": {"miles_squared": 88630, "kilometres_squared": 229550.65},
    "military": "Local militias, numerous mercenary companies and adventuring groups, most notably the Silver Ravens",
    "languages": ["Common", "Chondathan"],
    "religion": ["Loviatar", "Shar", "Sune", "Tymora", "Waukeen"],
    "economy": {
        "exports": ["Books", "food", "livestock", "pottery", "spiced sausage", "silk", "weapons", "wine"],
        "imports": ["Anything"],
    },
    "sources": [
        "Pirates of the Fallen Stars (Curtis Scott, 1992)",
        "Forgotten Realms Campaign Setting, 2nd Edition (Jeff Grubb, Ed Greenwood, Julia Martin, 1993)",
        "Sea of Fallen Stars (Steven E. Schend, 1999)",
        "Forgotten Realms Campaign Setting, 3rd Edition (Ed Greenwood, Sean K. Reynolds, Skip Williams, Rob Heinsoo, 2001)",
    ],
}

# %%
sespech_data = {
    "region": "Sespech",
    "ruler": "Baron Aldorn Thuragar",
    "capital": {"name": "Ormpetarr", "population": 55037},
    "settlements": [
        {"name": "Elbulder", "population": 12701},
        {"name": "Fort Arran", "population": 1000},
        {"name": "Mimph", "population": 27518},
        {"name": "Nagaford", "population": None},
        {"name": "Roaringford", "population": None},
    ],
    "population": {
        "total": 952560,
        "breakdown": {"human": 96, "dwarf": 2, "elf": 1, "misc.": 1},
        "density": {"per_mile_squared": 6.98, "per_kilometre_squared": 2.69},
    },
    "area": {"miles_squared": 136486, "kilometres_squared": 353497},
    "military": "Militias, a strong standing garrison at Fort Arran, cavalry companies based in the capital and mercenary companies, most notably the Band of Iron",
    "languages": ["Common", "Chondathan", "Shaaran (southern border areas)"],
    "religion": ["Eldath", "Helm", "Lliira", "Malar", "Talos", "Tempus", "Waukeen"],
    "economy": {
        "exports": ["Horses", "mercenaries", "salt"],
        "imports": ["Metal"],
    },
    "sources": ["The Vilhon Reach (Jim Butler, 1996)"],
}

# %%
sossal_data = {
    "region": "Sossal",
    "ruler": "The Circle of the Frozen Sun (druidic order)",
    "capital": "Sundice",
    "settlements": {
        "Sundice": {"population": 0},  # Population data is not specified
        "Dharvil": {"population": None},  # Population data is not specified
        "Naupau": {"population": None},  # Population data is not specified
        "Shannath": {"population": None},  # Population data is not specified
        "Uldfest": {"population": None},  # Population data is not specified
    },
    "area": {"miles_squared": 363151, "kilometres_squared": 940556.772},
    "military": "Local militias and a strong warrior culture",
    "languages": [
        "Common (with a Damaran influence)",
        "Uluik (along the Great Glacier)",
        "Sossrim",
        "Skaevrym (Sossrim dialect)",
    ],
    "religion": ["Auril (benign aspect)"],
    "economy": {
        "exports": ["Dwarven weapons", "silver", "various kinds of meat"],
        "imports": ["Fine wooden furniture", "furs", "gold", "seal meat"],
    },
    "sources": [
        "Dwarves Deep (Ed Greenwood, 1990)",
        "The Great Glacier (Rick Swan, 1992)",
        "Warriors and Priests of the Realms (John Terra, 1996)",
        "Forgotten Realms Campaign Setting, 3rd Edition (Ed Greenwood, Sean K. Reynolds, Skip Williams, Rob Heinsoo, 2001)",
        "The Grand History of the Realms (Brian R. James, Ed Greenwood, 2007)",
    ],
}

# %%
tethyr_data = {
    "region": "Tethyr",
    "ruler": "Queen Zaranda Star Rhindaun and King-Consort Haedrak Rhindaun III",
    "capital": {"name": "Darromar", "population": 68520},
    "settlements": [
        {"name": "Abbor", "population": None},
        {"name": "Banshivale", "population": None},
        {"name": "Barrowsmorn", "population": None},
        {"name": "Brost", "population": 7000},
        {"name": "Cayr Thalwood", "population": None},
        {"name": "Colbertann", "population": None},
        {"name": "Daraqadim", "population": None},
        {"name": "Dunod", "population": None},
        {"name": "Elbencourt", "population": None},
        {"name": "Fort Agis", "population": 316},
        {"name": "Fort Calim", "population": None},
        {"name": "Fort Teqlar", "population": 316},
        {"name": "Grapton", "population": None},
        {"name": "Hostim", "population": None},
        {"name": "Ithal Pass", "population": None},
        {"name": "Jhaansciim", "population": None},
        {"name": "Khanall", "population": None},
        {"name": "Kirgard", "population": None},
        {"name": "Krennasar", "population": None},
        {"name": "Kzelter", "population": None},
        {"name": "Lhestyn’s Hearth", "population": None},
        {"name": "Loranse", "population": None},
        {"name": "Lyllburg", "population": None},
        {"name": "Marakir", "population": None},
        {"name": "Maratimmir", "population": None},
        {"name": "Masamount", "population": None},
        {"name": "Monguldarath", "population": None},
        {"name": "Morninggold Keep", "population": None},
        {"name": "Mosstone", "population": 1713},
        {"name": "Mount Noblesse", "population": None},
        {"name": "Myratma", "population": 51390},
        {"name": "Myth Dyraalis", "population": None},
        {"name": "Nomerritin", "population": None},
        {"name": "Pansemil", "population": None},
        {"name": "Port Kir", "population": 7000},
        {"name": "Qian Hillfort", "population": None},
        {"name": "Riatavin", "population": 85650},
        {"name": "Rock Orchard", "population": None},
        {"name": "Ruba", "population": None},
        {"name": "Saharkhan", "population": None},
        {"name": "Saradush", "population": 39000},
        {"name": "Shelshyr House", "population": None},
        {"name": "Sulduskoonar", "population": None},
        {"name": "Survale Ford", "population": None},
        {"name": "Tannitton", "population": None},
        {"name": "Toaketh", "population": None},
        {"name": "Toralth", "population": None},
        {"name": "Trailstone", "population": 420},
        {"name": "Tulmene", "population": 3600},
        {"name": "Tweyar", "population": None},
        {"name": "Upparkol", "population": None},
        {"name": "Valtreth", "population": None},
        {"name": "Velen", "population": 14389},
        {"name": "Vineshade", "population": 3200},
        {"name": "Viperstongue", "population": None},
        {"name": "Zazesspur", "population": 116485},
    ],
    "population": {
        "total": 3771360,
        "breakdown": {"human": 76, "halfling": 20, "elf": 3, "misc.": 1},
        "density": {"per_mile_squared": 8.86, "per_kilometre_squared": 3.42},
    },
    "area": {"miles_squared": 425497, "kilometres_squared": 1102032.17},
    "military": "The Royal Army of Tethyr, the Royal Navy of Tethyr, various mercenary companies",
    "languages": ["Common", "Chondathan", "Alzhedo"],
    "religion": ["Chauntea", "Eldath", "Helm", "Ilmater", "the Seldarine (in the Forest of Tethir)", "Siamorphe", "Silvanus", "Torm", "Tyr"],
    "economy": {
        "exports": ["Ambergris", "carpets", "cheese", "cloth", "fish", "fruit", "livestock", "nuts", "pearls", "pipeweed", "rugs", "silk", "tea", "vegetables", "wine", "whale oil"],
        "imports": ["Magic items", "mercenaries", "spices", "weapons"],
    },
    "sources": ["Empires of the Sands (1988)", "Lands of Intrigue (1997)"],
}

# %%
thay_data = {
    "region": "Thay",
    "ruler": "The Council of Zulkirs",
    "capital": {"name": "Eltabbar", "population": 123120},
    "settlements": [
        {"name": "Amruthar", "population": 41040},
        {"name": "Anhaurz", "population": None},
        {"name": "Ankhur", "population": None},
        {"name": "Belizir", "population": None},
        {"name": "Bezantur", "population": 136800},
        {"name": "Delabbar", "population": None},
        {"name": "Denzar", "population": None},
        {"name": "Escalant", "population": 28728},
        {"name": "Ezreket", "population": None},
        {"name": "Hurkh", "population": None},
        {"name": "Keluthar", "population": None},
        {"name": "Mophur", "population": None},
        {"name": "Murbant", "population": 5000},
        {"name": "Nethentir", "population": 1872},
        {"name": "Nethjet", "population": None},
        {"name": "Nurethretos", "population": None},
        {"name": "Pyrados", "population": 50000},
        {"name": "Sefriszar", "population": None},
        {"name": "Sekelmur", "population": None},
        {"name": "Solzepar", "population": None},
        {"name": "Surag", "population": None},
        {"name": "Surthay", "population": 17784},
        {"name": "Szul", "population": None},
        {"name": "Thasselen", "population": 10000},
        {"name": "Thazrumaros", "population": None},
        {"name": "Tyraturos", "population": 58000},
        {"name": "Umratharos", "population": None},
        {"name": "Whitebranch", "population": 800},
        {"name": "Zolum", "population": None}
    ],
    "population": {
        "total": 4924800,
        "breakdown": {"human": 62, "gnoll": 10, "orc": 10, "dwarf": 8, "goblin": 5, "halfling": 4, "misc.": 1},
        "density": {"per_mile_squared": 13.99, "per_kilometre_squared": 5.40},
    },
    "area": {"miles_squared": 351777, "kilometres_squared": 911098.247},
    "military": "The Gnoll Legion, the Griffon Legion, the Undead Legion, hundreds of Red Wizards skilled at battle magic, various allied orc tribes, some mercenary forces",
    "languages": ["Common", "Dwarven", "Goblinoid", "Gnoll", "Halfling", "Mulhorandi", "Orc", "Thayan"],
    "religion": ["Bane", "Cyric", "Gargauth", "Kelemvor", "Kossuth", "Loviatar", "Malar", "Shar", "Talona", "Umberlee", "the Mulhorandi pantheon (among the Mulan and slaves)"],
    "economy": {
        "exports": ["Artwork", "fruit", "grains", "jewellery", "magic items", "scriptures", "timber"],
        "imports": ["Iron", "magic items", "monsters", "slaves", "spells"],
    },
    "sources": ["Dreams of the Red Wizards (Steve Perrin, 1988)", "Spellbound (Anthony Pryor, 1995)", "Unapproachable East (Richard Baker, Matt Forbeck, Sean K. Reynolds, 2003)"],
}

# %%
thesk_data = {
    "region": "Thesk",
    "ruler": "Merchant council",
    "capital": {"name": "Effectively none", "influence": "Telflamm (pop. 23,361)"},
    "settlements": [
        {"name": "Culdorn", "population": None},
        {"name": "Ethvale", "population": None},
        {"name": "Fullpoint", "population": None},
        {"name": "Hill Town", "population": None},
        {"name": "Inkar", "population": None},
        {"name": "Milvarune", "population": 6029},
        {"name": "Nyth", "population": 11501},
        {"name": "Phent", "population": None},
        {"name": "Phsant", "population": 21564},
        {"name": "Tammar", "population": 3594},
        {"name": "Thassalra", "population": None},
        {"name": "Two-Stars", "population": 4854},
        {"name": "Tezir-on-the-Marsh (Ethdale, Gref’s Ferry and Culmaster hold fealty to Telflamm)", "population": None},
    ],
    "population": {
        "total": 855360,
        "breakdown": {"human": 85, "gnome": 8, "orc": 6, "misc.": 1},
        "density": {"per_mile_squared": 5.10, "per_kilometre_squared": 1.97},
    },
    "area": {"miles_squared": 167745, "kilometres_squared": 434457.556},
    "military": "Mercenary companies, some local militias",
    "languages": ["Common", "Damaran"],
    "religion": ["Chauntea", "Cyric", "Mask", "Shaundakul", "Tymora", "Waukeen"],
    "economy": {
        "exports": ["Food", "gnome goods", "iron", "Kara-Turan goods"],
        "imports": ["Gold", "horses", "trade goods"],
    },
    "sources": ["Spellbound (Anthony Pryor, 1995)", "Unapproachable East (Richard Baker, Matt Forbeck, Sean K. Reynolds, 2003)"],
}

# %%
turmish_data = {
    "region": "Turmish",
    "ruler": "The Assembly of Stars, chaired by Lord Herengar",
    "capital": {"name": "Alaghôn", "population": 75000},
    "settlements": [
        {"name": "Ayakar", "population": None},
        {"name": "Banathar", "population": None},
        {"name": "Bistal’s Bottom", "population": None},
        {"name": "Centaur Bridge", "population": None},
        {"name": "Daroush", "population": 0},
        {"name": "Dauntshield", "population": None},
        {"name": "Faerie Well", "population": None},
        {"name": "Five Lions", "population": None},
        {"name": "Gildenglade", "population": 48384},
        {"name": "Holdensword", "population": None},
        {"name": "Illowwood", "population": None},
        {"name": "Ironcloak", "population": None},
        {"name": "Ironfang Deep", "population": None},
        {"name": "Jathrin’s Jump", "population": None},
        {"name": "Karthoon", "population": None},
        {"name": "Merrydell", "population": None},
        {"name": "Moonhunt Down", "population": None},
        {"name": "Morningstar Hollows", "population": None},
        {"name": "Nonthal", "population": 12902},
        {"name": "Peldrathan’s Pool", "population": None},
        {"name": "Oberiner’s Well", "population": None},
        {"name": "Quorngar", "population": None},
        {"name": "Ravilar’s Cloak", "population": None},
        {"name": "Regalia", "population": None},
        {"name": "Sambryntyn", "population": None},
        {"name": "Starfall", "population": None},
        {"name": "Swordslake Creek", "population": None},
        {"name": "Tamring", "population": None},
        {"name": "Ulver’s Lance", "population": None},
        {"name": "Velorn’s Valor", "population": None},
        {"name": "Vollermore", "population": None},
        {"name": "Wyvernstone", "population": None},
        {"name": "Xorhun", "population": None},
        {"name": "Zustild", "population": None},
    ],
    "population": {
        "total": 1693440,
        "breakdown": {"human": 78, "dwarf": 9, "halfling": 5, "elf": 3, "gnome": 2, "half-elf": 1, "half-orc": 1, "misc.": 1},
        "density": {"per_mile_squared": 12.41, "per_kilometre_squared": 4.79},
    },
    "area": {"miles_squared": 136421, "kilometres_squared": 353328.768},
    "military": "Local militias, a strong standing navy and various mercenary companies, most notably the Call to Arms",
    "languages": ["Common", "Chondathan", "Turmic"],
    "religion": ["Chauntea", "Eldath", "Helm", "Lliira", "Loviatar", "Nobanion", "Silvanus", "Selûne", "Tempus", "Tyr"],
    "economy": {
        "exports": ["Glass", "grain", "lumber", "mercenaries", "salt"],
        "imports": ["Luxury goods", "metal"],
    },
    "sources": ["Elminster’s Everwinking Eye: Mysterious Turmish (Ed Greenwood in Polyhedron #96, 1994)", "Elminster’s Everwinking Eye: A Treasure Tour of Turmish (Ed Greenwood in Polyhedron #103, 1995)", "Vilhon Reach (Jim Butler & Ed Greenwood, 1996)", "The Jewel of Turmish (Mel Odom, 2002)"],
}

# %%
ulgarth_data = {
    "region": "Ulgarth",
    "ruler": "King Drasna Bluemantle",
    "capital": {"name": "Orvyltar", "population": 21000},
    "settlements": [
        {"name": "Dralpur", "population": 8000},
        {"name": "Esbresh", "population": None},
        {"name": "Halahanyl", "population": None},
        {"name": "Kaspar", "population": 10000},
        {"name": "Kelazzan", "population": 5000},
        {"name": "Kellesar", "population": None},
        {"name": "Ravvan", "population": None},
        {"name": "Suntar", "population": None},
        {"name": "Suormpar", "population": None},
        {"name": "Surbar", "population": 15000},
    ],
    "population": {
        "total": None,
        "breakdown": {"human": "mostly", "dwarf": "small numbers", "halfling": "small numbers"},
        "density": {"per_mile_squared": None, "per_kilometre_squared": None},
    },
    "area": {"miles_squared": 275434, "kilometres_squared": 713371},
    "military": "A strong standing army and fleet",
    "languages": ["Common", "Devic", "Durpari"],
    "religion": ["Lathander", "Torm", "Tymora", "Tyr"],
    "economy": {
        "exports": ["Mingari", "foodstuffs"],
        "imports": ["Exotic goods", "horses", "spices", "foodstuffs", "textiles"],
    },
    "sources": ["The Shining South (Tom Prusa, 1993)", "Blood & Magic (video game, Tachyon Studios/Interplay, 1996)", "Faces of Deception (Troy Denning, 1998)", "the Double Diamond Triangle Saga (J. Robert King, James M. Ward, David Wise, Ed Greenwood, Roger E. Moore, Dave Gross, David Cook, Peter Archer, Richard Baker, 1998)", "Darkly, Through a Glass of Ale (Peter Archer in Realms of Mystery, 1998)"],
}

# %%
great_rift_data = {
    "region": "The Great Rift",
    "ruler": "Queen Karriva of Clan Simmerforge and the Council of Deep Lords",
    "capital": {"name": "Underhome", "population": 49650},
    "settlements": [
        {"name": "Daunting", "population": 12000},
        {"name": "Eartheart", "population": 44008},
        {"name": "Firecaverns", "population": 39000},
        {"name": "Glitterdelve", "population": 26000},
        {"name": "Hall of Echoes", "population": 9000},
        {"name": "Hammer & Anvil", "population": 8000},
        {"name": "Harlending", "population": 11000},
        {"name": "Khôltar", "population": 7643},
        {"name": "Magkstok", "population": None},
        {"name": "Rimmator", "population": 10500},
        {"name": "Sundasz", "population": 8000},
        {"name": "Tarnhall", "population": None},
        {"name": "Thuulurn", "population": 5600},
    ],
    "population": {
        "total": 1308960,
        "breakdown": {"dwarves": None, "gnomes": None, "halflings": None, "human": None},
        "density": {"per_mile_squared": None, "per_kilometre_squared": None},
    },
    "area": {"miles_squared": "incalculable", "kilometres_squared": "incalculable"},
    "military": "The Steel Shields, a standing army of 14,000 headquartered in Eartheart; the Peacehammer aerial cavalry, consisting of dwarven griffon-riders, who can quickly traverse the length of the Great Rift",
    "languages": ["Common", "Dwarven"],
    "religion": ["The dwarven pantheon, particularly Moradin Soulforger, Clangeddin Silverbeard, Dugmaren Brightmantle, and Haela Brightaxe"],
    "economy": {
        "exports": ["Gems", "gold", "jewellery", "magic items", "silver"],
        "imports": ["Fruit", "grain", "livestock", "produce"],
    },
    "sources": ["Dwarves Deep (Ed Greenwood, 1990)", "Underdark (Bruce R. Cordell, Gwendolyn F.M. Kestrel, Jeff Quick, 2003)", "Shining South (Thomas M. Reid, 2004)"],
}

# %%
unther_data = {
    "region": "Unther",
    "ruler": "Various local militias, bureaucrats, criminals and the Northern Wizards of Messemprar",
    "capital": {"name": "Unthalass", "population": 164627},
    "settlements": [
        {"name": "Dalath", "population": 6000},
        {"name": "Firetrees", "population": 7000},
        {"name": "Kaoll", "population": None},
        {"name": "Messemprar", "population": 98776},
        {"name": "Red Haven", "population": 1500},
        {"name": "Sadamzar", "population": None},
        {"name": "Shussel", "population": 9150},
        {"name": "Ssintar", "population": 4000},
    ],
    "population": {
        "total": 4263940,
        "breakdown": {"human": 94, "dwarf": 3, "halfling": 2, "misc.": 1},
        "density": {"per_mile_squared": 13.94, "per_kilometre_squared": 5.38},
    },
    "area": {"miles_squared": 305889, "kilometres_squared": 792248.873},
    "military": "None, the Untheric Army has effectively dissolved following the God-King’s death; some cities maintain local militias",
    "languages": ["Common", "Mulhorandi", "Untheric"],
    "religion": ["Assuran (Hoar)", "Bane", "Mystra", "Tempus", "Tiamat", "the Mulhorandi pantheon", "some hold-outs still worship the Untheric pantheon, despite the latter’s effective dissolution"],
    "economy": {
        "exports": ["Ceramics", "cloth", "gold", "iron", "minerals", "sculpture", "seed oil"],
        "imports": ["Food", "mercenaries", "slaves", "weapons"],
    },
    "sources": ["Old Empires (Scott Bennie, 1990)", "Powers and Pantheons (Eric L. Boyd, 1997)", "Dragons of Faerûn (Eric L. Boyd, Eytan Bernstein, 2006)"],
}

# %%
threskel_data = {
    "region": "Threskel",
    "ruler": "The Great Bone King Alasklerbanbastos the Undying, a powerful dracolich, claims dominion over all of Threskel and parts of Chessenta",
    "capital": {"name": "Mourktar", "population": 10107},
    "settlements": [
        {"name": "Thamor", "population": 5163},
    ],
    "population": {
        "total": 52781,
        "breakdown": {"human": 93, "duergar": 2, "dragonkin": 2, "troll": 1, "half-dragons": 1, "misc.": 1},
        "density": {"per_mile_squared": 1.75, "per_kilometre_squared": 0.68},
    },
    "area": {"miles_squared": 30151, "kilometres_squared": 78090.732},
    "military": "Local militias",
    "languages": ["Common", "Mulhorandi", "Untheric"],
    "religion": ["Bane", "the Mulhorandi pantheon", "Tchazzar", "Tempus", "Tiamat"],
    "economy": {
        "exports": ["Crops", "fish", "horses", "precious metals"],
        "imports": ["Food", "weapons"],
    },
    "sources": ["Dragons of Faerûn (Eric L. Boyd, Eytan Bernstein, 2006)"],
}

# %%
waterdeep_data = {
    "region": "Waterdeep",
    "ruler": "The Lords of Waterdeep, represented by Open Lord Piergeiron Paladinson",
    "capital": {"name": "Waterdeep", "population": 132661},
    "settlements": [
        {"name": "Amphail", "population": 600},
        {"name": "Rassalantar", "population": 200},
        {"name": "Tharqualnaar", "population": 517},
        {"name": "T’Quession", "population": 240},
        {"name": "Zundbridge", "population": None},
    ],
    "population": {
        "total": 1347840,
        "breakdown": {"human": 64, "dwarf": 10, "elf": 10, "halfling": 5, "half-elf": 5, "gnome": 3, "half-orc": 2, "misc.": 1},
        "density": {"per_mile_squared": 21, "per_kilometre_squared": 8.41},
    },
    "area": {"miles_squared": 61853, "kilometres_squared": 160198.53},
    "military": "The City Guard (inc. the Griffon Legion), the City Watch, Force Grey, various mercenary and adventuring companies, the clergy of Tempus, a formidable number of resident powerful mages and clerics",
    "languages": ["Common", "Chondathan", "Dwarven", "Elven", "Gnome", "Halfling", "Illuskan"],
    "religion": ["Baravar Cloakshadow", "Deneir", "Gond", "Lathander", "Mielikki", "Mystra", "Oghma", "Selûne", "Sharess", "Siamorphe", "Silvanus", "Sune", "Tempus", "Tymora", "Tyr"],
    "economy": {
        "exports": ["Ale", "arms", "cloth", "fish", "furnishings", "leather goods", "pottery", "refined metals", "finished goods"],
        "imports": ["Grain", "livestock", "leather", "ore", "timber", "exotic goods from other lands"],
    },
    "sources": [
        "Waterdeep and the North (Ed Greenwood, 1987)",
        "The Savage Frontier (Jennell Jaquays, 1988)",
        "City System (Jeff Grubb, Ed Greenwood, 1988)",
        "Eye of the Beholder (video game, Westwood Studios, 1991)",
        "Eye of the Beholder II: The Legend of Darkmoon (video game, Westwood Studios, 1992)",
        "City of Splendors (Steven E. Schend, Ed Greenwood, 1994)",
        "Volo’s Guide to Waterdeep (Ed Greenwood, 1994)",
        "The North (slade, Ed Greenwood, Jeff Grubb, Julia Martin, Steven E. Schend, Jennell Jaquays, Steve Perrin, 1996)",
        "City of Splendors: Waterdeep (Eric L. Boyd, 2005)",
        "Environs of Waterdeep (Eric L. Boyd, 2006)",
    ],
}

# %%
regions_and_nations = [
    amn_data,
    calimshan_data,
    chessenta_data,
    chondath_data,
    cormyr_data,
    damara_data,
    durpar_data,
    halruaa_data,
    impiltur_data,
    moonshae_data,
    nimbral_data,
    rashemen_data,
    samarach_data,
    thindol_data,
    tashalar_data,
    sembia_data,
    sespech_data,
    sossal_data,
    tethyr_data,
    thay_data,
    thesk_data,
    turmish_data,
    ulgarth_data,
    great_rift_data,
    unther_data,
    threskel_data,
    waterdeep_data,
    aglarond_data,
    dambrath_data,
    erlkazar_data,
    evereska_data,
    evermeet_data,
    gundarlun_data,
    ruathym_data,
    trisk_data,
    tuern_data,
    hartsvale_data,
    lantan_data,
    lapaliiya_data,
    tharsult_data,
    luiren_data,
    silver_marches_data,
    mintarn_data,
    orlumbor_data,
    moonshae_data,
    mulhorand_data,
    murghom_data,
    semphar_data,
    narfell_data,
]

# %%
import pandas as pd

def create_dataframe(regions_and_nations):
    # Create an empty list to store data rows
    data_rows = []

    # Iterate through each nation/region
    for region_data in regions_and_nations:
        # Extract region-specific data
        region_name = region_data["region"]
        ruler = region_data.get("ruler", "")
        population_data = region_data.get("population", "")
        population = population_data.get("total", "") if isinstance(population_data, dict) else population_data
        area = region_data.get("area", {}).get("miles_squared", "")
        military = region_data.get("military", "")
        languages = ", ".join([str(lang) for lang in region_data.get("languages", [])])
        religion = ", ".join([str(rel) for rel in region_data.get("religion", [])])
        economy = region_data.get("economy", {})
        exports = ", ".join([str(exp) for exp in (economy.get("exports") or [])])
        imports = ", ".join([str(imp) for imp in (economy.get("imports") or [])])
        sources = ", ".join([str(src) for src in region_data.get("sources", [])])

        capital_data = region_data.get("capital", {})
        if isinstance(capital_data, dict):
            capital_name = capital_data.get("name", "")
            capital_population = capital_data.get("population", "")
        else:
            capital_name = capital_data
            capital_population = ""

        capital_row = [capital_name, region_name, capital_name, capital_population, population, area, ruler, military, languages, religion, exports, imports, sources]
        data_rows.append(capital_row)

        settlements_data = region_data.get("settlements", [])
        for settlement_data in settlements_data:
            if isinstance(settlement_data, dict):
                settlement_name = settlement_data.get("name", "")
                settlement_population = settlement_data.get("population", "")
            else:
                settlement_name = settlement_data
                settlement_population = ""

            settlement_row = [settlement_name, region_name, capital_name, settlement_population, population, area, ruler, military, languages, religion, exports, imports, sources]
            data_rows.append(settlement_row)

            df = pd.DataFrame(data_rows, columns=[
            "Settlement",
            "Region",
            "Capital",
            "Settlement_Population",
            "Region_Population",
            "Area",
            "Ruler",
            "Military",
            "Languages",
            "Religions",
            "Exports",
            "Imports",
            "Sources"
        ])

    return df

# Create the DataFrame
df = create_dataframe(regions_and_nations)

# Display the DataFrame
df.head()
# Out:
#          Settlement Region   Capital Settlement_Population Region_Population  \
# 0          Athkatla    Amn  Athkatla                118304           2963520
# 1          Amnwater    Amn  Athkatla                  7500           2963520
# 2     Citadel Amnur    Amn  Athkatla                   700           2963520
# 3  Citadel Rashturl    Amn  Athkatla                   700           2963520
# 4         Coryllvol    Amn  Athkatla                                 2963520
#
#   Area               Ruler                                           Military  \
# 0       The Council of Six  Varies (largely dependent on mercenary companies)
# 1       The Council of Six  Varies (largely dependent on mercenary companies)
# 2       The Council of Six  Varies (largely dependent on mercenary companies)
# 3       The Council of Six  Varies (largely dependent on mercenary companies)
# 4       The Council of Six  Varies (largely dependent on mercenary companies)
#
# ...
